# %% [markdown]
# # Landing Zone
#
# This notebook contains the different steps involved steps in the the extraction of data and its storage in the landing zone of our data management pipeline. Particularly, the following scripts are responsible of the following tasks:
# 1. Environment setup, such as the preparation of the data lake (based on MinIO)
# 2. Obtaining of data from datasources
# 3. Raw data storaging into the temporal landing
# 4. Data shipment from temporal landing to persistent landing
#
# ## Environment Setup
# Before starting to get data from datasources it is needed to prepare our temporal landing. As said before, we will be using MinIO, an S3-compatible object storage implementation, as a data lake to store data as it comes. Before continuing, ensure that a MinIO instance is up and running, which can be done easily with Docker Compose (see the main [README](../../README.md) file for more information).
#
# First of all, we will connect to the MinIo instance, create a bucket for the landing zone and a subfolder that will correspond to the temporal landing. To interact with MinIO programatically we will use the [boto3](https://boto3.amazonaws.com/v1/documentation/api/latest/guide/s3-example-creating-buckets.html) Python library.

# %%
import boto3
import os
from dotenv import load_dotenv

load_dotenv()
access_key_id = os.getenv("ACCESS_KEY_ID")
secret_access_key = os.getenv("SECRET_ACCESS_KEY")
minio_url = "http://" + os.getenv("S3_API_ENDPOINT")


minio_client = boto3.client(
    "s3",
    aws_access_key_id=access_key_id,
    aws_secret_access_key=secret_access_key,
    endpoint_url=minio_url
)

new_bucket = "landing-zone"
try:
    minio_client.create_bucket(Bucket=new_bucket)
except (minio_client.exceptions.BucketAlreadyExists, minio_client.exceptions.BucketAlreadyOwnedByYou):
    print(f"Bucket '{new_bucket}' already exists")

# %% [markdown]
# # Obtaining data from datasources
# After the connection to the MinIO has been done and the first bucket created, now we need to obtain the data from the different data sources. This datasources have already been created in the first part of the script so we only need to retrieve them and import them into the temporal landing zone inside MinIO.

# %%
import os
DATASET_COUNT = 3
for i in range(1, DATASET_COUNT + 1):
    dataset_path = f"../../output/dataset{i}/"
    for root, dirs, files in os.walk(dataset_path):
        for file in files:
            file_path = os.path.join(root, file)
            try:
                minio_client.upload_file(file_path, new_bucket, file)
                print(f"Uploaded {file} to s3://{new_bucket}/{file}")
            except Exception as e:
                print(f"Failed to upload {file}: {e}")
# Out:
# Uploaded ISIC_0028948.jpg to s3://landing-zone/ISIC_0028948.jpg
# Uploaded ISIC_0032493.jpg to s3://landing-zone/ISIC_0032493.jpg
# Uploaded ISIC_0033786.jpg to s3://landing-zone/ISIC_0033786.jpg
# Uploaded ISIC_0027077.jpg to s3://landing-zone/ISIC_0027077.jpg
# Uploaded ISIC_0031831.jpg to s3://landing-zone/ISIC_0031831.jpg
# Uploaded ISIC_0032150.jpg to s3://landing-zone/ISIC_0032150.jpg
# Uploaded ISIC_0033053.jpg to s3://landing-zone/ISIC_0033053.jpg
# Uploaded ISIC_0025118.jpg to s3://landing-zone/ISIC_0025118.jpg
# Uploaded ISIC_0029896.jpg to s3://landing-zone/ISIC_0029896.jpg
# Uploaded ISIC_0030269.jpg to s3://landing-zone/ISIC_0030269.jpg
# Uploaded ISIC_0029649.jpg to s3://landing-zone/ISIC_0029649.jpg
# Uploaded ISIC_0025874.jpg to s3://landing-zone/ISIC_0025874.jpg
# Uploaded ISIC_0030197.jpg to s3://landing-zone/ISIC_0030197.jpg
# Uploaded ISIC_0033055.jpg to s3://landing-zone/ISIC_0033055.jpg
# Uploaded ISIC_0025430.jpg to s3://landing-zone/ISIC_0025430.jpg
# Uploaded ISIC_0027209.jpg to s3://landing-zone/ISIC_0027209.jpg
# Uploaded ISIC_0032218.jpg to s3://landing-zone/ISIC_0032218.jpg
# Uploaded ISIC_0026507.jpg to s3://landing-zone/ISIC_0026507.jpg
# Uploaded melanoma.txt to s3://landing-zone/melanoma.txt
# Uploaded squamous_cell_carcinoma.txt to s3://landing-zone/squamous_cell_carcinoma.txt
# Uploaded basal_cell_carcinoma.txt to s3://landing-zone/basal_cell_carcinoma.txt
# Uploaded skin_cancer.txt to s3://landing-zone/skin_cancer.txt
# Uploaded actinic_keratosis.txt to s3://landing-zone/actinic_keratosis.txt
# Uploaded answer_38.wav to s3://landing-zone/answer_38.wav
# Uploaded answer_44.wav to s3://landing-zone/answer_44.wav
# Uploaded answer_10.wav to s3://landing-zone/answer_10.wav
# Uploaded answer_33.wav to s3://landing-zone/answer_33.wav
# Uploaded answer_63.wav to s3://landing-zone/answer_63.wav
# Uploaded answer_98.wav to s3://landing-zone/answer_98.wav
# Uploaded answer_47.wav to s3://landing-zone/answer_47.wav
# Uploaded answer_41.wav to s3://landing-zone/answer_41.wav
# Uploaded answer_62.wav to s3://landing-zone/answer_62.wav
# Uploaded answer_74.wav to s3://landing-zone/answer_74.wav
# Uploaded answer_12.wav to s3://landing-zone/answer_12.wav
# Uploaded answer_99.wav to s3://landing-zone/answer_99.wav
# Uploaded answer_90.wav to s3://landing-zone/answer_90.wav
# Uploaded answer_81.wav to s3://landing-zone/answer_81.wav
# Uploaded answer_49.wav to s3://landing-zone/answer_49.wav
# Uploaded answer_65.wav to s3://landing-zone/answer_65.wav
# Uploaded answer_15.wav to s3://landing-zone/answer_15.wav
# Uploaded answer_36.wav to s3://landing-zone/answer_36.wav
# Uploaded answer_8.wav to s3://landing-zone/answer_8.wav
# Uploaded answer_21.wav to s3://landing-zone/answer_21.wav
# Uploaded answer_34.wav to s3://landing-zone/answer_34.wav
# Uploaded answer_0.wav to s3://landing-zone/answer_0.wav
# Uploaded answer_70.wav to s3://landing-zone/answer_70.wav
# Uploaded answer_11.wav to s3://landing-zone/answer_11.wav
# Uploaded answer_18.wav to s3://landing-zone/answer_18.wav
# Uploaded answer_4.wav to s3://landing-zone/answer_4.wav
# Uploaded answer_35.wav to s3://landing-zone/answer_35.wav
# Uploaded answer_30.wav to s3://landing-zone/answer_30.wav
# Uploaded answer_1.wav to s3://landing-zone/answer_1.wav
# Uploaded answer_54.wav to s3://landing-zone/answer_54.wav
# Uploaded answer_55.wav to s3://landing-zone/answer_55.wav
# Uploaded answer_22.wav to s3://landing-zone/answer_22.wav
# Uploaded answer_31.wav to s3://landing-zone/answer_31.wav
# Uploaded answer_27.wav to s3://landing-zone/answer_27.wav
# Uploaded answer_59.wav to s3://landing-zone/answer_59.wav
# Uploaded answer_16.wav to s3://landing-zone/answer_16.wav
# Uploaded answer_39.wav to s3://landing-zone/answer_39.wav
# Uploaded answer_68.wav to s3://landing-zone/answer_68.wav
# Uploaded answer_50.wav to s3://landing-zone/answer_50.wav
# Uploaded answer_24.wav to s3://landing-zone/answer_24.wav
# Uploaded answer_2.wav to s3://landing-zone/answer_2.wav
# Uploaded answer_14.wav to s3://landing-zone/answer_14.wav
# Uploaded answer_82.wav to s3://landing-zone/answer_82.wav
# Uploaded answer_69.wav to s3://landing-zone/answer_69.wav
# Uploaded answer_43.wav to s3://landing-zone/answer_43.wav
# Uploaded answer_45.wav to s3://landing-zone/answer_45.wav
# Uploaded answer_57.wav to s3://landing-zone/answer_57.wav
# Uploaded answer_28.wav to s3://landing-zone/answer_28.wav
# Uploaded answer_89.wav to s3://landing-zone/answer_89.wav
# Uploaded answer_93.wav to s3://landing-zone/answer_93.wav
# Uploaded answer_61.wav to s3://landing-zone/answer_61.wav
# Uploaded answer_37.wav to s3://landing-zone/answer_37.wav
# Uploaded answer_66.wav to s3://landing-zone/answer_66.wav
# Uploaded answer_7.wav to s3://landing-zone/answer_7.wav
# Uploaded answer_96.wav to s3://landing-zone/answer_96.wav
# Uploaded answer_76.wav to s3://landing-zone/answer_76.wav
# Uploaded answer_26.wav to s3://landing-zone/answer_26.wav
# Uploaded answer_58.wav to s3://landing-zone/answer_58.wav
# Uploaded answer_92.wav to s3://landing-zone/answer_92.wav
# Uploaded answer_71.wav to s3://landing-zone/answer_71.wav
# Uploaded answer_19.wav to s3://landing-zone/answer_19.wav
# Uploaded answer_67.wav to s3://landing-zone/answer_67.wav
# Uploaded answer_77.wav to s3://landing-zone/answer_77.wav
# Uploaded answer_86.wav to s3://landing-zone/answer_86.wav
# Uploaded answer_25.wav to s3://landing-zone/answer_25.wav
# Uploaded answer_73.wav to s3://landing-zone/answer_73.wav
# Uploaded answer_17.wav to s3://landing-zone/answer_17.wav
# Uploaded answer_48.wav to s3://landing-zone/answer_48.wav
# Uploaded answer_20.wav to s3://landing-zone/answer_20.wav
# Uploaded answer_97.wav to s3://landing-zone/answer_97.wav
# Uploaded answer_85.wav to s3://landing-zone/answer_85.wav
# Uploaded answer_94.wav to s3://landing-zone/answer_94.wav
# Uploaded answer_87.wav to s3://landing-zone/answer_87.wav
# Uploaded answer_3.wav to s3://landing-zone/answer_3.wav
# Uploaded answer_78.wav to s3://landing-zone/answer_78.wav
# Uploaded answer_91.wav to s3://landing-zone/answer_91.wav
# Uploaded answer_64.wav to s3://landing-zone/answer_64.wav
# Uploaded answer_29.wav to s3://landing-zone/answer_29.wav
# Uploaded answer_56.wav to s3://landing-zone/answer_56.wav
# Uploaded answer_83.wav to s3://landing-zone/answer_83.wav
# Uploaded answer_40.wav to s3://landing-zone/answer_40.wav
# Uploaded answer_52.wav to s3://landing-zone/answer_52.wav
# Uploaded answer_88.wav to s3://landing-zone/answer_88.wav
# Uploaded answer_5.wav to s3://landing-zone/answer_5.wav
# Uploaded answer_32.wav to s3://landing-zone/answer_32.wav
# Uploaded answer_6.wav to s3://landing-zone/answer_6.wav
# Uploaded answer_46.wav to s3://landing-zone/answer_46.wav
# Uploaded answer_79.wav to s3://landing-zone/answer_79.wav
# Uploaded answer_13.wav to s3://landing-zone/answer_13.wav
# Uploaded answer_23.wav to s3://landing-zone/answer_23.wav
# Uploaded answer_75.wav to s3://landing-zone/answer_75.wav
# Uploaded answer_95.wav to s3://landing-zone/answer_95.wav
# Uploaded answer_72.wav to s3://landing-zone/answer_72.wav
# Uploaded answer_84.wav to s3://landing-zone/answer_84.wav
# Uploaded answer_42.wav to s3://landing-zone/answer_42.wav
# Uploaded answer_60.wav to s3://landing-zone/answer_60.wav
# Uploaded answer_51.wav to s3://landing-zone/answer_51.wav
# Uploaded answer_80.wav to s3://landing-zone/answer_80.wav
# Uploaded answer_9.wav to s3://landing-zone/answer_9.wav
# Uploaded answer_53.wav to s3://landing-zone/answer_53.wav
