# %%
import boto3
from botocore.exceptions import ClientError
import os
from dotenv import load_dotenv

load_dotenv()
access_key_id = os.getenv("ACCESS_KEY_ID")
secret_access_key = os.getenv("SECRET_ACCESS_KEY")
minio_url = "http://" + os.getenv("S3_API_ENDPOINT")


minio_client = boto3.client(
    "s3",
    aws_access_key_id=access_key_id,
    aws_secret_access_key=secret_access_key,
    endpoint_url=minio_url
)

minio_bucket = "training-preparation-zone"
manifest_name = "dataset_train.json"
local_file = "./dataset_train.json"

# %%
new_bucket2 = "augmentation-zone"
try:
    minio_client.create_bucket(Bucket=new_bucket2)
except ClientError as e:
    error_code = e.response['Error']['Code']
    if error_code in ['BucketAlreadyExists', 'BucketAlreadyOwnedByYou']:
        print(f"Bucket '{new_bucket2}' already exists")
# Out:
# Bucket 'augmentation-zone' already exists

# %%
new_bucket = "training-preparation-zone"
try:
    minio_client.create_bucket(Bucket=new_bucket)
except ClientError as e:
    error_code = e.response['Error']['Code']
    if error_code in ['BucketAlreadyExists', 'BucketAlreadyOwnedByYou']:
        print(f"Bucket '{new_bucket}' already exists")
    else:
        print(f"Error creating bucket: {e}")
# Out:
# Bucket 'training-preparation-zone' already exists

# %% [markdown]
# ## Copy data
#
# We first will copy the data from one zone to the other so we can keep track of the changes being made to the data.

# %%
source_bucket = "exploitation-zone"

response = minio_client.list_objects_v2(Bucket=source_bucket)
if 'Contents' in response:
    for obj in response['Contents']:
        copy_source = {'Bucket': source_bucket, 'Key': obj['Key']}
        minio_client.copy_object(CopySource=copy_source, Bucket=new_bucket, Key=obj['Key'])
        print(f"Copied {obj['Key']} from {source_bucket} to {new_bucket}")
else:
    print(f"No objects found in bucket '{source_bucket}'.")
# Out:
# Copied images/ISIC_0024388.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0024508.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0024853.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0025118.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0025200.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0025202.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0025298.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0025343.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0025430.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0025806.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0025874.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0025886.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0025899.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0025960.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0026077.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0026128.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0026152.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0026283.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0026289.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0026507.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0026653.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0026710.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0026803.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0026911.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0027058.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0027077.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0027209.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0027219.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0027249.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0027307.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0027620.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0027710.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0027841.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0027999.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0028025.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0028103.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0028175.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0028280.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0028381.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0028416.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0028726.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0028948.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0029024.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0029220.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0029263.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0029475.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0029577.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0029623.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0029649.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0029694.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0029834.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0029851.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0029876.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0029896.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0029929.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0030055.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0030197.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0030269.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0030297.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0030397.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0030413.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0030421.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0030492.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0030541.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0031256.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0031351.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0031380.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0031442.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0031655.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0031831.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0031948.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0031981.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0031987.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0032000.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0032110.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0032150.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0032218.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0032415.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0032493.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0032563.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0032701.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0032727.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0032731.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0032871.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0033053.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0033055.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0033103.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0033154.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0033229.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0033439.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0033464.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0033466.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0033505.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0033786.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0034016.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0034128.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0034129.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0034144.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0034196.png from exploitation-zone to training-preparation-zone
# Copied images/ISIC_0034222.png from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_0.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_1.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_10.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_11.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_12.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_13.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_14.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_15.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_16.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_17.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_18.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_19.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_2.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_20.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_21.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_22.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_23.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_24.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_25.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_26.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_27.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_28.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_29.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_3.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_30.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_31.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_32.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_33.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_34.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_35.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_36.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_37.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_38.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_39.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_4.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_40.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_41.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_42.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_5.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_6.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_7.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_8.txt from exploitation-zone to training-preparation-zone
# Copied texts/actinic_keratosis_0_0_9.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_0.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_1.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_10.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_11.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_12.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_13.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_14.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_15.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_16.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_17.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_18.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_19.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_2.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_20.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_21.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_22.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_23.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_24.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_25.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_26.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_27.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_28.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_29.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_3.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_30.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_31.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_32.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_33.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_34.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_35.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_36.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_37.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_38.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_39.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_4.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_40.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_41.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_42.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_43.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_44.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_45.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_46.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_47.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_48.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_49.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_5.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_50.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_51.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_52.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_53.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_54.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_55.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_56.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_57.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_58.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_59.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_6.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_60.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_61.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_62.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_63.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_64.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_65.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_66.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_67.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_68.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_69.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_7.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_70.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_71.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_72.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_73.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_8.txt from exploitation-zone to training-preparation-zone
# Copied texts/basal_cell_carcinoma_0_0_9.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_0.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_1.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_10.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_100.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_101.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_102.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_103.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_104.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_105.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_106.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_107.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_108.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_109.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_11.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_110.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_111.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_112.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_113.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_114.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_115.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_116.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_117.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_118.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_119.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_12.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_120.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_121.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_122.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_123.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_124.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_125.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_126.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_127.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_128.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_129.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_13.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_130.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_131.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_132.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_133.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_134.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_135.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_136.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_137.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_138.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_139.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_14.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_140.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_141.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_142.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_143.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_144.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_145.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_146.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_147.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_148.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_149.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_15.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_150.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_151.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_152.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_153.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_154.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_155.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_156.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_157.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_158.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_159.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_16.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_160.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_161.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_162.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_163.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_164.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_165.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_166.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_167.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_168.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_169.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_17.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_170.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_171.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_172.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_173.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_174.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_175.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_176.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_177.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_178.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_179.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_18.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_180.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_181.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_182.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_183.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_184.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_185.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_186.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_187.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_188.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_189.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_19.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_190.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_2.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_20.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_21.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_22.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_23.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_24.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_25.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_26.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_27.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_28.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_29.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_3.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_30.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_31.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_32.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_33.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_34.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_35.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_36.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_37.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_38.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_39.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_4.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_40.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_41.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_42.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_43.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_44.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_45.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_46.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_47.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_48.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_49.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_5.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_50.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_51.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_52.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_53.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_54.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_55.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_56.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_57.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_58.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_59.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_6.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_60.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_61.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_62.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_63.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_64.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_65.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_66.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_67.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_68.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_69.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_7.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_70.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_71.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_72.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_73.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_74.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_75.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_76.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_77.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_78.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_79.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_8.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_80.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_81.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_82.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_83.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_84.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_85.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_86.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_87.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_88.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_89.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_9.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_90.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_91.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_92.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_93.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_94.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_95.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_96.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_97.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_98.txt from exploitation-zone to training-preparation-zone
# Copied texts/melanoma_0_0_99.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_0.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_1.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_10.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_11.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_12.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_13.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_14.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_15.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_16.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_17.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_18.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_19.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_2.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_20.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_21.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_22.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_23.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_24.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_25.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_26.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_27.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_28.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_29.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_3.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_30.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_31.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_32.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_33.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_34.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_35.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_36.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_37.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_38.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_39.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_4.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_40.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_41.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_42.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_43.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_44.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_45.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_46.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_47.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_48.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_49.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_5.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_50.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_51.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_52.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_53.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_54.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_55.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_56.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_57.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_58.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_59.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_6.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_60.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_61.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_62.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_63.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_64.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_65.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_66.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_67.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_68.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_69.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_7.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_70.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_71.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_72.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_73.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_74.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_75.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_76.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_77.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_78.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_79.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_8.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_80.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_81.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_82.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_83.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_84.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_85.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_86.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_87.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_88.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_89.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_9.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_90.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_91.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_92.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_93.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_94.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_95.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_96.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_97.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_98.txt from exploitation-zone to training-preparation-zone
# Copied texts/skin_cancer_0_0_99.txt from exploitation-zone to training-preparation-zone
# Copied texts/squamous_cell_carcinoma_0_0_0.txt from exploitation-zone to training-preparation-zone
# Copied texts/squamous_cell_carcinoma_0_0_1.txt from exploitation-zone to training-preparation-zone
# Copied texts/squamous_cell_carcinoma_0_0_2.txt from exploitation-zone to training-preparation-zone
# Copied texts/squamous_cell_carcinoma_0_0_3.txt from exploitation-zone to training-preparation-zone
# Copied texts/squamous_cell_carcinoma_0_0_4.txt from exploitation-zone to training-preparation-zone
# Copied texts/squamous_cell_carcinoma_0_0_5.txt from exploitation-zone to training-preparation-zone
# Copied texts/squamous_cell_carcinoma_0_0_6.txt from exploitation-zone to training-preparation-zone

# %%
import chromadb
import json
client = chromadb.HttpClient(host="localhost", port=8000)

collection = client.get_collection("text_multimodal_collection")
collection_image = client.get_collection("image_multimodal_collection")
objects = collection.get(include=["metadatas", "documents"])
text_data = collection.get(
    include=["embeddings", "metadatas", "documents"]
)
text_embeddings = text_data["embeddings"]

dataset_pairs = []

results = collection_image.query(
    query_embeddings=text_embeddings,
    n_results=1,
    include=["metadatas", "documents", "distances"],
)
print(results)

for i, text_path in enumerate(text_data["ids"]):
    best_image_path = results["ids"][i][0]
    score = results["distances"][i][0]
    dataset_pairs.append({
        "image": best_image_path,
        "text": text_path,
        "score": score
    })
local_filename = "dataset_train.json"
with open(local_filename, "w") as f:
    json.dump(dataset_pairs, f)

minio_client.upload_file(local_filename, new_bucket, local_filename)
# Out:
# {'ids': [['images/ISIC_0027249.png'], ['images/ISIC_0027058.png'], ['images/ISIC_0026152.png'], ['images/ISIC_0026803.png'], ['images/ISIC_0026077.png'], ['images/ISIC_0026803.png'], ['images/ISIC_0027058.png'], ['images/ISIC_0027249.png'], ['images/ISIC_0031987.png'], ['images/ISIC_0028103.png'], ['images/ISIC_0029475.png'], ['images/ISIC_0025960.png'], ['images/ISIC_0027999.png'], ['images/ISIC_0026152.png'], ['images/ISIC_0031987.png'], ['images/ISIC_0031380.png'], ['images/ISIC_0029220.png'], ['images/ISIC_0025874.png'], ['images/ISIC_0031442.png'], ['images/ISIC_0025960.png'], ['images/ISIC_0032110.png'], ['images/ISIC_0033505.png'], ['images/ISIC_0031831.png'], ['images/ISIC_0027058.png'], ['images/ISIC_0031981.png'], ['images/ISIC_0030197.png'], ['images/ISIC_0032415.png'], ['images/ISIC_0032727.png'], ['images/ISIC_0029694.png'], ['images/ISIC_0029929.png'], ['images/ISIC_0029263.png'], ['images/ISIC_0025960.png'], ['images/ISIC_0034196.png'], ['images/ISIC_0032731.png'], ['images/ISIC_0032415.png'], ['images/ISIC_0027077.png'], ['images/ISIC_0032415.png'], ['images/ISIC_0027058.png'], ['images/ISIC_0033103.png'], ['images/ISIC_0033103.png'], ['images/ISIC_0031380.png'], ['images/ISIC_0028025.png'], ['images/ISIC_0034196.png'], ['images/ISIC_0031380.png'], ['images/ISIC_0029577.png'], ['images/ISIC_0033229.png'], ['images/ISIC_0034222.png'], ['images/ISIC_0027077.png'], ['images/ISIC_0027058.png'], ['images/ISIC_0027077.png'], ['images/ISIC_0031442.png'], ['images/ISIC_0031831.png'], ['images/ISIC_0025886.png'], ['images/ISIC_0031380.png'], ['images/ISIC_0026077.png'], ['images/ISIC_0032150.png'], ['images/ISIC_0034222.png'], ['images/ISIC_0032415.png'], ['images/ISIC_0031831.png'], ['images/ISIC_0031380.png'], ['images/ISIC_0027249.png'], ['images/ISIC_0029263.png'], ['images/ISIC_0032110.png'], ['images/ISIC_0027710.png'], ['images/ISIC_0032110.png'], ['images/ISIC_0024388.png'], ['images/ISIC_0031831.png'], ['images/ISIC_0031442.png'], ['images/ISIC_0027058.png'], ['images/ISIC_0032415.png'], ['images/ISIC_0027219.png'], ['images/ISIC_0033786.png'], ['images/ISIC_0034196.png'], ['images/ISIC_0034196.png'], ['images/ISIC_0031380.png'], ['images/ISIC_0026803.png'], ['images/ISIC_0031380.png'], ['images/ISIC_0026507.png'], ['images/ISIC_0032415.png'], ['images/ISIC_0031380.png'], ['images/ISIC_0034016.png'], ['images/ISIC_0027058.png'], ['images/ISIC_0030492.png'], ['images/ISIC_0026128.png'], ['images/ISIC_0031987.png'], ['images/ISIC_0031380.png'], ['images/ISIC_0034196.png'], ['images/ISIC_0031380.png'], ['images/ISIC_0029220.png'], ['images/ISIC_0033786.png'], ['images/ISIC_0032563.png'], ['images/ISIC_0031380.png'], ['images/ISIC_0032415.png'], ['images/ISIC_0024853.png'], ['images/ISIC_0027620.png'], ['images/ISIC_0033786.png'], ['images/ISIC_0027058.png'], ['images/ISIC_0032110.png'], ['images/ISIC_0025874.png'], ['images/ISIC_0032110.png'], ['images/ISIC_0027219.png'], ['images/ISIC_0033786.png'], ['images/ISIC_0031380.png'], ['images/ISIC_0026152.png'], ['images/ISIC_0027077.png'], ['images/ISIC_0034222.png'], ['images/ISIC_0034222.png'], ['images/ISIC_0032731.png'], ['images/ISIC_0031831.png'], ['images/ISIC_0034222.png'], ['images/ISIC_0032150.png'], ['images/ISIC_0024388.png'], ['images/ISIC_0027249.png'], ['images/ISIC_0030055.png'], ['images/ISIC_0027249.png'], ['images/ISIC_0027077.png'], ['images/ISIC_0031831.png'], ['images/ISIC_0032110.png'], ['images/ISIC_0025118.png'], ['images/ISIC_0027249.png'], ['images/ISIC_0027249.png'], ['images/ISIC_0031442.png'], ['images/ISIC_0032727.png'], ['images/ISIC_0027077.png'], ['images/ISIC_0032150.png'], ['images/ISIC_0031380.png'], ['images/ISIC_0031442.png'], ['images/ISIC_0026283.png'], ['images/ISIC_0029851.png'], ['images/ISIC_0031380.png'], ['images/ISIC_0027249.png'], ['images/ISIC_0027077.png'], ['images/ISIC_0027249.png'], ['images/ISIC_0025960.png'], ['images/ISIC_0031442.png'], ['images/ISIC_0032731.png'], ['images/ISIC_0027249.png'], ['images/ISIC_0029 ...

# %% [markdown]
# ## Transforming images while maintaining the same embedding
#
# Here, we transform the images (data augmentation) while keeping the embedding of the original image, so that both share the same semantic representation.

# %%
def apply_transformations(image):
    """Aplica transformaciones aleatorias a la imagen"""
    transformations = []
    
    # Rotación aleatoria
    if random.random() > 0.5:
        angle = random.randint(-15, 15)
        image = image.rotate(angle, expand=False, fillcolor='white')
        transformations.append(f"rotated_{angle}")
    
    # Ajuste de brillo
    if random.random() > 0.5:
        enhancer = ImageEnhance.Brightness(image)
        factor = random.uniform(0.8, 1.2)
        image = enhancer.enhance(factor)
        transformations.append(f"brightness_{factor:.2f}")
    
    # Ajuste de contraste
    if random.random() > 0.5:
        enhancer = ImageEnhance.Contrast(image)
        factor = random.uniform(0.8, 1.2)
        image = enhancer.enhance(factor)
        transformations.append(f"contrast_{factor:.2f}")
    
    # Flip horizontal
    if random.random() > 0.5:
        image = ImageOps.mirror(image)
        transformations.append("flipped")
    
    return image, transformations

# %%
import io
from PIL import Image, ImageEnhance, ImageOps
import random
import chromadb
import time
import boto3

# Conectar a ChromaDB
chroma_client = chromadb.HttpClient(host="localhost", port=8000)
collection_image = chroma_client.get_collection("image_multimodal_collection")

# Obtener todas las imágenes del bucket training-preparation-zone
source_bucket = "exploitation-zone"
destination_bucket = "augmentation-zone"
# Función para cargar embedder solo si es necesario (lazy loading para evitar cargar el modelo si no hay espacio)
_embed_image_cache = None
def get_embed_image():
    """Carga el embedder solo cuando es necesario (con caché)"""
    global _embed_image_cache
    if _embed_image_cache is None:
        import sys
        sys.path.append('/Users/carlesaguilera/Desktop/ADSDB2/ADSDB/Part2')
        from src.embedder import embed_image
        _embed_image_cache = embed_image
    return _embed_image_cache

# Listar solo imágenes
response = minio_client.list_objects_v2(Bucket=source_bucket, Prefix="images/")


if 'Contents' in response:
    transformed_count = 0
    for obj in response['Contents']:
        if obj['Key'].endswith(('.png', '.jpg', '.jpeg', '.PNG', '.JPG', '.JPEG')):
            try:
                # Pequeño delay antes de descargar para evitar rate limiting
                time.sleep(0.05)
                
                # Descargar imagen original
                image_obj = minio_client.get_object(Bucket=source_bucket, Key=obj['Key'])
                image_data = image_obj['Body'].read()
                original_image = Image.open(io.BytesIO(image_data))
                
                # Obtener el embedding de la imagen original desde ChromaDB
                original_embedding = None
                original_id = obj['Key']
                
                try:
                    result = collection_image.get(ids=[original_id], include=["embeddings"])
                    if result['ids'] and len(result['embeddings']) > 0:
                        original_embedding = result['embeddings'][0]
                        print(f"Embedding encontrado para {original_id}")
                    else:
                        # Si no existe, intentar generar el embedding (solo si hay espacio)
                        print(f"⚠ Embedding NO encontrado para {original_id}")
                        print(f"⚠ Intentando generar embedding (requiere espacio en disco ~1.7GB)...")
                        # Cargar embedder solo si es necesario
                        try:
                            embed_image_fn = get_embed_image()
                        except Exception as load_error:
                            print(f"✗ Error cargando modelo CLIP: {load_error}")
                            print(f"✗ No se puede generar embedding. Saltando esta imagen.")
                            continue
                        
                        try:
                            original_embedding = embed_image_fn(original_image)
                            # Guardar el embedding de la original si no existía
                            # Guardamos la imagen original en la lista de imágenes asociadas
                            collection_image.add(
                                ids=[original_id],
                                embeddings=[original_embedding],
                                metadatas=[{
                                    "type": "original", 
                                    "image_type": "original",
                                    "associated_images": original_id  # Lista inicial con solo la original
                                }]
                            )
                            print(f"✓ Embedding generado y guardado para {original_id}")
                        except Exception as gen_error:
                            print(f"✗ Error generando embedding: {gen_error}")
                            print(f"✗ Saltando esta imagen.")
                            continue
                except Exception as e:
                    # Si no existe en ChromaDB, intentar generar el embedding
                    print(f"⚠ Error obteniendo embedding para {original_id}: {e}")
                    print(f"⚠ Intentando generar embedding (requiere espacio en disco ~1.7GB)...")
                    # Cargar embedder solo si es necesario
                    try:
                        embed_image_fn = get_embed_image()
                    except Exception as load_error:
                        print(f"✗ Error cargando modelo CLIP: {load_error}")
                        print(f"✗ No se puede generar embedding. Saltando esta imagen.")
                        continue
                    
                    try:
                        original_embedding = embed_image_fn(original_image)
                        # Guardar el embedding de la original
                        try:
                            collection_image.add(
                                ids=[original_id],
                                embeddings=[original_embedding],
                                metadatas=[{
                                    "type": "original", 
                                    "image_type": "original",
                                    "associated_images": original_id  # Lista inicial con solo la original
                                }]
                            )
                        except:
                            # Si ya existe, actualizar con el embedding
                            collection_image.update(
                                ids=[original_id],
                                embeddings=[original_embedding],
                                metadatas=[{
                                    "type": "original", 
                                    "image_type": "original",
                                    "associated_images": original_id
                                }]
                            )
                        print(f"✓ Embedding generado y guardado para {original_id}")
                    except Exception as gen_error:
                        print(f"✗ Error generando embedding: {gen_error}")
                        print(f"✗ Saltando esta imagen.")
                        continue
                
                # Aplicar transformaciones
                transformed_image, transformations = apply_transformations(original_image.copy())
                
                # Crear nombre para la imagen transformada
                base_name = obj['Key'].replace('images/', '').replace('.png', '').replace('.jpg', '').replace('.jpeg', '')
                transform_suffix = '_'.join(transformations) if transformations else 'augmented'
                new_key = f"images/{base_name}_{transform_suffix}.png"
                
                # Guardar imagen transformada en buffer
                buffer = io.BytesIO()
                transformed_image.save(buffer, format='PNG')
                buffer.seek(0)
                # Obtener los datos del buffer como bytes

                buffer_data = buffer.getvalue()
                # Subir imagen transformada a MinIO usando put_object
                minio_client.put_object(
                    Bucket=destination_bucket,
                    Key=new_key,
                    Body=buffer_data,
                    ContentType='image/png'
                )
                # Delay más largo para evitar rate limiting de MinIO
                time.sleep(0.2)
                # Pequeño delay para evitar rate limiting de MinIO
                time.sleep(0.1)
                
                # En lugar de crear un nuevo registro, actualizamos el registro original
                # para agregar la imagen transformada a la lista de imágenes asociadas
                try:
                    # Obtener los metadatos actuales del registro original
                    current_result = collection_image.get(ids=[original_id], include=["metadatas"])
                    current_metadata = current_result['metadatas'][0] if current_result['metadatas'] and current_result['metadatas'][0] else {}
                    
                    # Obtener la lista actual de imágenes asociadas
                    if 'associated_images' in current_metadata:
                        # Si ya existe, puede ser un string o una lista
                        if isinstance(current_metadata['associated_images'], str):
                            associated_images = current_metadata['associated_images'].split(',')
                        else:
                            associated_images = current_metadata['associated_images'] if isinstance(current_metadata['associated_images'], list) else [current_metadata['associated_images']]
                    else:
                        # Si no existe, empezar con la imagen original
                        associated_images = [original_id]
                    
                    # Agregar la nueva imagen transformada a la lista
                    if new_key not in associated_images:
                        associated_images.append(new_key)
                    
                    # Actualizar el registro original con la nueva lista de imágenes asociadas
                    collection_image.update(
                        ids=[original_id],
                        embeddings=[original_embedding],  # Mantener el mismo embedding
                        metadatas=[{
                            "type": "original",
                            "image_type": "original",
                            "associated_images": ','.join(associated_images),  # Lista de todas las imágenes (original + transformadas)
                            "transformations_info": f"{new_key}:{', '.join(transformations) if transformations else 'none'}"  # Info de transformaciones
                        }]
                    )
                    print(f"✓ Imagen transformada agregada al embedding de {original_id}")
                except Exception as e:
                    print(f"⚠ Error actualizando embedding para {original_id}: {e}")
                    # Si falla, intentar crear el registro original si no existe
                    try:
                        collection_image.add(
                            ids=[original_id],
                            embeddings=[original_embedding],
                            metadatas=[{
                                "type": "original",
                                "image_type": "original",
                                "associated_images": f"{original_id},{new_key}"
                            }]
                        )
                        print(f"✓ Registro creado con ambas imágenes")
                    except Exception as create_error:
                        print(f"✗ Error creando registro: {create_error}")
                
                transformed_count += 1
                print(f"  Transformada: {original_id} -> {new_key}")
                print(f"  Imagen agregada a la lista de imágenes asociadas del embedding")
                print(f"  Transformaciones: {', '.join(transformations) if transformations else 'ninguna'}")
                
            except Exception as e:
                print(f"Error procesando {obj['Key']}: {e}")
                import traceback
                traceback.print_exc()
                continue
    
    print(f"\nProceso completado: {transformed_count} imágenes transformadas")
    print(f" En ChromaDB: cada embedding único está almacenado UNA SOLA VEZ")
    print(f" con todas sus imágenes asociadas (original + transformadas) en los metadatos")
else:
    print(f"No se encontraron imágenes en el bucket '{source_bucket}'.")
# Out:
# Embedding encontrado para images/ISIC_0024388.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0024388.png
#   Transformada: images/ISIC_0024388.png -> images/ISIC_0024388_contrast_1.07.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: contrast_1.07
# Embedding encontrado para images/ISIC_0024508.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0024508.png
#   Transformada: images/ISIC_0024508.png -> images/ISIC_0024508_rotated_-12_contrast_0.98_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_-12, contrast_0.98, flipped
# Embedding encontrado para images/ISIC_0024853.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0024853.png
#   Transformada: images/ISIC_0024853.png -> images/ISIC_0024853_contrast_1.07.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: contrast_1.07
# Embedding encontrado para images/ISIC_0025118.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0025118.png
#   Transformada: images/ISIC_0025118.png -> images/ISIC_0025118_rotated_15_brightness_0.96_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_15, brightness_0.96, flipped
# Embedding encontrado para images/ISIC_0025200.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0025200.png
#   Transformada: images/ISIC_0025200.png -> images/ISIC_0025200_rotated_6_contrast_0.89_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_6, contrast_0.89, flipped
# Embedding encontrado para images/ISIC_0025202.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0025202.png
#   Transformada: images/ISIC_0025202.png -> images/ISIC_0025202_rotated_15_contrast_1.13.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_15, contrast_1.13
# Embedding encontrado para images/ISIC_0025298.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0025298.png
#   Transformada: images/ISIC_0025298.png -> images/ISIC_0025298_rotated_13_brightness_1.02_contrast_1.10_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_13, brightness_1.02, contrast_1.10, flipped
# Embedding encontrado para images/ISIC_0025343.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0025343.png
#   Transformada: images/ISIC_0025343.png -> images/ISIC_0025343_brightness_0.93_contrast_1.00_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: brightness_0.93, contrast_1.00, flipped
# Embedding encontrado para images/ISIC_0025430.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0025430.png
#   Transformada: images/ISIC_0025430.png -> images/ISIC_0025430_rotated_-15_brightness_0.81_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_-15, brightness_0.81, flipped
# Embedding encontrado para images/ISIC_0025806.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0025806.png
#   Transformada: images/ISIC_0025806.png -> images/ISIC_0025806_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: flipped
# Embedding encontrado para images/ISIC_0025874.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0025874.png
#   Transformada: images/ISIC_0025874.png -> images/ISIC_0025874_brightness_0.81_contrast_0.83_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: brightness_0.81, contrast_0.83, flipped
# Embedding encontrado para images/ISIC_0025886.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0025886.png
#   Transformada: images/ISIC_0025886.png -> images/ISIC_0025886_brightness_0.88.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: brightness_0.88
# Embedding encontrado para images/ISIC_0025899.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0025899.png
#   Transformada: images/ISIC_0025899.png -> images/ISIC_0025899_brightness_1.13.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: brightness_1.13
# Embedding encontrado para images/ISIC_0025960.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0025960.png
#   Transformada: images/ISIC_0025960.png -> images/ISIC_0025960_rotated_7.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_7
# Embedding encontrado para images/ISIC_0026077.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0026077.png
#   Transformada: images/ISIC_0026077.png -> images/ISIC_0026077_rotated_-3_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_-3, flipped
# Embedding encontrado para images/ISIC_0026128.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0026128.png
#   Transformada: images/ISIC_0026128.png -> images/ISIC_0026128_rotated_11_brightness_1.00_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_11, brightness_1.00, flipped
# Embedding encontrado para images/ISIC_0026152.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0026152.png
#   Transformada: images/ISIC_0026152.png -> images/ISIC_0026152_rotated_-2_brightness_0.95_contrast_1.03.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_-2, brightness_0.95, contrast_1.03
# Embedding encontrado para images/ISIC_0026283.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0026283.png
#   Transformada: images/ISIC_0026283.png -> images/ISIC_0026283_augmented.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: ninguna
# Embedding encontrado para images/ISIC_0026289.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0026289.png
#   Transformada: images/ISIC_0026289.png -> images/ISIC_0026289_rotated_2_brightness_1.05.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_2, brightness_1.05
# Embedding encontrado para images/ISIC_0026507.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0026507.png
#   Transformada: images/ISIC_0026507.png -> images/ISIC_0026507_brightness_1.16_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: brightness_1.16, flipped
# Embedding encontrado para images/ISIC_0026653.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0026653.png
#   Transformada: images/ISIC_0026653.png -> images/ISIC_0026653_brightness_0.94.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: brightness_0.94
# Embedding encontrado para images/ISIC_0026710.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0026710.png
#   Transformada: images/ISIC_0026710.png -> images/ISIC_0026710_augmented.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: ninguna
# Embedding encontrado para images/ISIC_0026803.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0026803.png
#   Transformada: images/ISIC_0026803.png -> images/ISIC_0026803_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: flipped
# Embedding encontrado para images/ISIC_0026911.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0026911.png
#   Transformada: images/ISIC_0026911.png -> images/ISIC_0026911_rotated_-3_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_-3, flipped
# Embedding encontrado para images/ISIC_0027058.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0027058.png
#   Transformada: images/ISIC_0027058.png -> images/ISIC_0027058_contrast_0.92.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: contrast_0.92
# Embedding encontrado para images/ISIC_0027077.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0027077.png
#   Transformada: images/ISIC_0027077.png -> images/ISIC_0027077_rotated_-4_brightness_1.06.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_-4, brightness_1.06
# Embedding encontrado para images/ISIC_0027209.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0027209.png
#   Transformada: images/ISIC_0027209.png -> images/ISIC_0027209_brightness_0.81.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: brightness_0.81
# Embedding encontrado para images/ISIC_0027219.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0027219.png
#   Transformada: images/ISIC_0027219.png -> images/ISIC_0027219_brightness_0.82_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: brightness_0.82, flipped
# Embedding encontrado para images/ISIC_0027249.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0027249.png
#   Transformada: images/ISIC_0027249.png -> images/ISIC_0027249_rotated_9_brightness_0.91.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_9, brightness_0.91
# Embedding encontrado para images/ISIC_0027307.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0027307.png
#   Transformada: images/ISIC_0027307.png -> images/ISIC_0027307_rotated_13_brightness_0.89.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_13, brightness_0.89
# Embedding encontrado para images/ISIC_0027620.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0027620.png
#   Transformada: images/ISIC_0027620.png -> images/ISIC_0027620_contrast_0.87_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: contrast_0.87, flipped
# Embedding encontrado para images/ISIC_0027710.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0027710.png
#   Transformada: images/ISIC_0027710.png -> images/ISIC_0027710_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: flipped
# Embedding encontrado para images/ISIC_0027841.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0027841.png
#   Transformada: images/ISIC_0027841.png -> images/ISIC_0027841_brightness_0.85.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: brightness_0.85
# Embedding encontrado para images/ISIC_0027999.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0027999.png
#   Transformada: images/ISIC_0027999.png -> images/ISIC_0027999_brightness_0.92.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: brightness_0.92
# Embedding encontrado para images/ISIC_0028025.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0028025.png
#   Transformada: images/ISIC_0028025.png -> images/ISIC_0028025_rotated_3_brightness_1.19_contrast_0.83_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_3, brightness_1.19, contrast_0.83, flipped
# Embedding encontrado para images/ISIC_0028103.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0028103.png
#   Transformada: images/ISIC_0028103.png -> images/ISIC_0028103_brightness_1.02_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: brightness_1.02, flipped
# Embedding encontrado para images/ISIC_0028175.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0028175.png
#   Transformada: images/ISIC_0028175.png -> images/ISIC_0028175_brightness_1.10_contrast_0.82.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: brightness_1.10, contrast_0.82
# Embedding encontrado para images/ISIC_0028280.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0028280.png
#   Transformada: images/ISIC_0028280.png -> images/ISIC_0028280_rotated_-15_brightness_0.94_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_-15, brightness_0.94, flipped
# Embedding encontrado para images/ISIC_0028381.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0028381.png
#   Transformada: images/ISIC_0028381.png -> images/ISIC_0028381_brightness_0.97_contrast_0.93.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: brightness_0.97, contrast_0.93
# Embedding encontrado para images/ISIC_0028416.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0028416.png
#   Transformada: images/ISIC_0028416.png -> images/ISIC_0028416_rotated_15_brightness_1.13.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_15, brightness_1.13
# Embedding encontrado para images/ISIC_0028726.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0028726.png
#   Transformada: images/ISIC_0028726.png -> images/ISIC_0028726_rotated_-7_brightness_1.01_contrast_0.83_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_-7, brightness_1.01, contrast_0.83, flipped
# Embedding encontrado para images/ISIC_0028948.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0028948.png
#   Transformada: images/ISIC_0028948.png -> images/ISIC_0028948_brightness_1.12_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: brightness_1.12, flipped
# Embedding encontrado para images/ISIC_0029024.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0029024.png
#   Transformada: images/ISIC_0029024.png -> images/ISIC_0029024_rotated_-9_brightness_1.00_contrast_0.83_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_-9, brightness_1.00, contrast_0.83, flipped
# Embedding encontrado para images/ISIC_0029220.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0029220.png
#   Transformada: images/ISIC_0029220.png -> images/ISIC_0029220_rotated_8_contrast_1.04_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_8, contrast_1.04, flipped
# Embedding encontrado para images/ISIC_0029263.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0029263.png
#   Transformada: images/ISIC_0029263.png -> images/ISIC_0029263_brightness_1.09_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: brightness_1.09, flipped
# Embedding encontrado para images/ISIC_0029475.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0029475.png
#   Transformada: images/ISIC_0029475.png -> images/ISIC_0029475_contrast_1.08_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: contrast_1.08, flipped
# Embedding encontrado para images/ISIC_0029577.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0029577.png
#   Transformada: images/ISIC_0029577.png -> images/ISIC_0029577_rotated_-4_contrast_1.08_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_-4, contrast_1.08, flipped
# Embedding encontrado para images/ISIC_0029623.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0029623.png
#   Transformada: images/ISIC_0029623.png -> images/ISIC_0029623_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: flipped
# Embedding encontrado para images/ISIC_0029649.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0029649.png
#   Transformada: images/ISIC_0029649.png -> images/ISIC_0029649_rotated_-8_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_-8, flipped
# Embedding encontrado para images/ISIC_0029694.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0029694.png
#   Transformada: images/ISIC_0029694.png -> images/ISIC_0029694_rotated_6_brightness_0.94_contrast_1.10.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_6, brightness_0.94, contrast_1.10
# Embedding encontrado para images/ISIC_0029834.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0029834.png
#   Transformada: images/ISIC_0029834.png -> images/ISIC_0029834_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: flipped
# Embedding encontrado para images/ISIC_0029851.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0029851.png
#   Transformada: images/ISIC_0029851.png -> images/ISIC_0029851_rotated_1_contrast_1.06_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_1, contrast_1.06, flipped
# Embedding encontrado para images/ISIC_0029876.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0029876.png
#   Transformada: images/ISIC_0029876.png -> images/ISIC_0029876_brightness_0.85.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: brightness_0.85
# Embedding encontrado para images/ISIC_0029896.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0029896.png
#   Transformada: images/ISIC_0029896.png -> images/ISIC_0029896_rotated_15_brightness_1.16_contrast_1.12.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_15, brightness_1.16, contrast_1.12
# Embedding encontrado para images/ISIC_0029929.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0029929.png
#   Transformada: images/ISIC_0029929.png -> images/ISIC_0029929_contrast_1.03.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: contrast_1.03
# Embedding encontrado para images/ISIC_0030055.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0030055.png
#   Transformada: images/ISIC_0030055.png -> images/ISIC_0030055_rotated_-2_brightness_1.13_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_-2, brightness_1.13, flipped
# Embedding encontrado para images/ISIC_0030197.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0030197.png
#   Transformada: images/ISIC_0030197.png -> images/ISIC_0030197_contrast_0.84_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: contrast_0.84, flipped
# Embedding encontrado para images/ISIC_0030269.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0030269.png
#   Transformada: images/ISIC_0030269.png -> images/ISIC_0030269_brightness_0.98_contrast_1.16.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: brightness_0.98, contrast_1.16
# Embedding encontrado para images/ISIC_0030297.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0030297.png
#   Transformada: images/ISIC_0030297.png -> images/ISIC_0030297_brightness_1.09_contrast_1.12_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: brightness_1.09, contrast_1.12, flipped
# Embedding encontrado para images/ISIC_0030397.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0030397.png
#   Transformada: images/ISIC_0030397.png -> images/ISIC_0030397_augmented.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: ninguna
# Embedding encontrado para images/ISIC_0030413.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0030413.png
#   Transformada: images/ISIC_0030413.png -> images/ISIC_0030413_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: flipped
# Embedding encontrado para images/ISIC_0030421.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0030421.png
#   Transformada: images/ISIC_0030421.png -> images/ISIC_0030421_rotated_10.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_10
# Embedding encontrado para images/ISIC_0030492.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0030492.png
#   Transformada: images/ISIC_0030492.png -> images/ISIC_0030492_brightness_1.07_contrast_0.82.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: brightness_1.07, contrast_0.82
# Embedding encontrado para images/ISIC_0030541.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0030541.png
#   Transformada: images/ISIC_0030541.png -> images/ISIC_0030541_brightness_0.82.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: brightness_0.82
# Embedding encontrado para images/ISIC_0031256.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0031256.png
#   Transformada: images/ISIC_0031256.png -> images/ISIC_0031256_brightness_0.99_contrast_1.11.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: brightness_0.99, contrast_1.11
# Embedding encontrado para images/ISIC_0031351.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0031351.png
#   Transformada: images/ISIC_0031351.png -> images/ISIC_0031351_rotated_7_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_7, flipped
# Embedding encontrado para images/ISIC_0031380.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0031380.png
#   Transformada: images/ISIC_0031380.png -> images/ISIC_0031380_rotated_-7_contrast_0.87_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_-7, contrast_0.87, flipped
# Embedding encontrado para images/ISIC_0031442.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0031442.png
#   Transformada: images/ISIC_0031442.png -> images/ISIC_0031442_rotated_-2_contrast_1.07.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_-2, contrast_1.07
# Embedding encontrado para images/ISIC_0031655.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0031655.png
#   Transformada: images/ISIC_0031655.png -> images/ISIC_0031655_brightness_1.07.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: brightness_1.07
# Embedding encontrado para images/ISIC_0031831.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0031831.png
#   Transformada: images/ISIC_0031831.png -> images/ISIC_0031831_contrast_0.87.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: contrast_0.87
# Embedding encontrado para images/ISIC_0031948.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0031948.png
#   Transformada: images/ISIC_0031948.png -> images/ISIC_0031948_rotated_13.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_13
# Embedding encontrado para images/ISIC_0031981.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0031981.png
#   Transformada: images/ISIC_0031981.png -> images/ISIC_0031981_rotated_3_brightness_1.18_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_3, brightness_1.18, flipped
# Embedding encontrado para images/ISIC_0031987.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0031987.png
#   Transformada: images/ISIC_0031987.png -> images/ISIC_0031987_rotated_7_contrast_1.05.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_7, contrast_1.05
# Embedding encontrado para images/ISIC_0032000.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0032000.png
#   Transformada: images/ISIC_0032000.png -> images/ISIC_0032000_rotated_-11.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_-11
# Embedding encontrado para images/ISIC_0032110.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0032110.png
#   Transformada: images/ISIC_0032110.png -> images/ISIC_0032110_rotated_-2_contrast_1.03.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_-2, contrast_1.03
# Embedding encontrado para images/ISIC_0032150.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0032150.png
#   Transformada: images/ISIC_0032150.png -> images/ISIC_0032150_rotated_-5_brightness_0.83_contrast_0.88_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_-5, brightness_0.83, contrast_0.88, flipped
# Embedding encontrado para images/ISIC_0032218.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0032218.png
#   Transformada: images/ISIC_0032218.png -> images/ISIC_0032218_rotated_0_brightness_0.90.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_0, brightness_0.90
# Embedding encontrado para images/ISIC_0032415.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0032415.png
#   Transformada: images/ISIC_0032415.png -> images/ISIC_0032415_contrast_0.94_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: contrast_0.94, flipped
# Embedding encontrado para images/ISIC_0032493.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0032493.png
#   Transformada: images/ISIC_0032493.png -> images/ISIC_0032493_contrast_1.03.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: contrast_1.03
# Embedding encontrado para images/ISIC_0032563.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0032563.png
#   Transformada: images/ISIC_0032563.png -> images/ISIC_0032563_rotated_7_brightness_1.02_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_7, brightness_1.02, flipped
# Embedding encontrado para images/ISIC_0032701.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0032701.png
#   Transformada: images/ISIC_0032701.png -> images/ISIC_0032701_rotated_11_brightness_0.83_contrast_1.13.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_11, brightness_0.83, contrast_1.13
# Embedding encontrado para images/ISIC_0032727.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0032727.png
#   Transformada: images/ISIC_0032727.png -> images/ISIC_0032727_brightness_1.18_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: brightness_1.18, flipped
# Embedding encontrado para images/ISIC_0032731.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0032731.png
#   Transformada: images/ISIC_0032731.png -> images/ISIC_0032731_rotated_3_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_3, flipped
# Embedding encontrado para images/ISIC_0032871.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0032871.png
#   Transformada: images/ISIC_0032871.png -> images/ISIC_0032871_brightness_0.82.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: brightness_0.82
# Embedding encontrado para images/ISIC_0033053.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0033053.png
#   Transformada: images/ISIC_0033053.png -> images/ISIC_0033053_rotated_1_contrast_0.95_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_1, contrast_0.95, flipped
# Embedding encontrado para images/ISIC_0033055.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0033055.png
#   Transformada: images/ISIC_0033055.png -> images/ISIC_0033055_rotated_-9_brightness_1.17_contrast_1.09.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_-9, brightness_1.17, contrast_1.09
# Embedding encontrado para images/ISIC_0033103.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0033103.png
#   Transformada: images/ISIC_0033103.png -> images/ISIC_0033103_rotated_12_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_12, flipped
# Embedding encontrado para images/ISIC_0033154.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0033154.png
#   Transformada: images/ISIC_0033154.png -> images/ISIC_0033154_contrast_0.95.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: contrast_0.95
# Embedding encontrado para images/ISIC_0033229.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0033229.png
#   Transformada: images/ISIC_0033229.png -> images/ISIC_0033229_brightness_0.88_contrast_1.19.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: brightness_0.88, contrast_1.19
# Embedding encontrado para images/ISIC_0033439.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0033439.png
#   Transformada: images/ISIC_0033439.png -> images/ISIC_0033439_contrast_1.11_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: contrast_1.11, flipped
# Embedding encontrado para images/ISIC_0033464.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0033464.png
#   Transformada: images/ISIC_0033464.png -> images/ISIC_0033464_rotated_0_contrast_1.04.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_0, contrast_1.04
# Embedding encontrado para images/ISIC_0033466.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0033466.png
#   Transformada: images/ISIC_0033466.png -> images/ISIC_0033466_rotated_-12_brightness_0.87.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_-12, brightness_0.87
# Embedding encontrado para images/ISIC_0033505.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0033505.png
#   Transformada: images/ISIC_0033505.png -> images/ISIC_0033505_rotated_-8_brightness_1.07_contrast_1.07_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_-8, brightness_1.07, contrast_1.07, flipped
# Embedding encontrado para images/ISIC_0033786.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0033786.png
#   Transformada: images/ISIC_0033786.png -> images/ISIC_0033786_brightness_0.93.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: brightness_0.93
# Embedding encontrado para images/ISIC_0034016.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0034016.png
#   Transformada: images/ISIC_0034016.png -> images/ISIC_0034016_contrast_0.95_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: contrast_0.95, flipped
# Embedding encontrado para images/ISIC_0034128.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0034128.png
#   Transformada: images/ISIC_0034128.png -> images/ISIC_0034128_brightness_0.94_contrast_1.04.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: brightness_0.94, contrast_1.04
# Embedding encontrado para images/ISIC_0034129.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0034129.png
#   Transformada: images/ISIC_0034129.png -> images/ISIC_0034129_rotated_-9_brightness_1.11_contrast_0.88.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_-9, brightness_1.11, contrast_0.88
# Embedding encontrado para images/ISIC_0034144.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0034144.png
#   Transformada: images/ISIC_0034144.png -> images/ISIC_0034144_rotated_7_contrast_1.14_flipped.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: rotated_7, contrast_1.14, flipped
# Embedding encontrado para images/ISIC_0034196.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0034196.png
#   Transformada: images/ISIC_0034196.png -> images/ISIC_0034196_augmented.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: ninguna
# Embedding encontrado para images/ISIC_0034222.png
# ✓ Imagen transformada agregada al embedding de images/ISIC_0034222.png
#   Transformada: images/ISIC_0034222.png -> images/ISIC_0034222_brightness_1.07.png
#   Imagen agregada a la lista de imágenes asociadas del embedding
#   Transformaciones: brightness_1.07
#
# Proceso completado: 100 imágenes transformadas
#  En ChromaDB: cada embedding único está almacenado UNA SOLA VEZ
#  con todas sus imágenes asociadas (original + transformadas) en los metadatos

# %% [markdown]
# ## Prove the validation of the new images transforme matching the same Embedding.
#
# Now we're going to print all the embeddings with all the images that have associated, so we can validate that the augmentation part have been done successfully.

# %%
import numpy as np

data = collection_image.get(include=["metadatas", "documents", "embeddings"])

# Ahora cada embedding tiene una lista de imágenes asociadas en los metadatos
print(f"Total de embeddings en ChromaDB: {len(data['ids'])}")
print("=" * 80)

total_images_count = 0
for idx, (embedding, img_id, metadata) in enumerate(zip(data["embeddings"], data["ids"], data["metadatas"])):
    print(f"\nEmbedding {idx + 1}:")
    print(f"  ID del registro: {img_id}")
    print(f"  Vector: {embedding[:5]}... (primeros 5 valores)")
    
    if metadata and 'associated_images' in metadata:
        # Obtener la lista de imágenes asociadas
        associated_images_str = metadata['associated_images']
        if isinstance(associated_images_str, str):
            associated_images = [img.strip() for img in associated_images_str.split(',')]
        else:
            associated_images = associated_images_str if isinstance(associated_images_str, list) else [associated_images_str]
        
        print(f"  Total de imágenes asociadas: {len(associated_images)}")
        print(f"  Imágenes asociadas:")
        for img in associated_images:
            print(f"    - {img}")
            total_images_count += 1
        
        # Mostrar información de transformaciones si existe
        if 'transformations_info' in metadata:
            print(f"  Info transformaciones: {metadata['transformations_info']}")
    else:
        # Si no hay associated_images, mostrar solo el ID del registro
        print(f"  Imagen: {img_id}")
        total_images_count += 1
    
    if metadata:
        print(f"  Otros metadatos: {metadata}")
    print("-" * 80)

print(f"\nResumen:")
print(f"  Total de embeddings únicos: {len(data['ids'])}")
print(f"  Total de imágenes (originales + transformadas): {total_images_count}")
# Out:
# Total de embeddings en ChromaDB: 259
# ================================================================================
#
# Embedding 1:
#   ID del registro: images/ISIC_0024388.png
#   Vector: [ 0.00830536  0.01662186 -0.01564987  0.04551699  0.0083858 ]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0024388.png
#     - images/ISIC_0024388_contrast_1.19_flipped.png
#   Info transformaciones: images/ISIC_0024388_contrast_1.19_flipped.png:contrast_1.19, flipped
#   Otros metadatos: {'associated_images': 'images/ISIC_0024388.png,images/ISIC_0024388_contrast_1.19_flipped.png', 'image_type': 'original', 'type': 'original', 'transformations_info': 'images/ISIC_0024388_contrast_1.19_flipped.png:contrast_1.19, flipped'}
# --------------------------------------------------------------------------------
#
# Embedding 2:
#   ID del registro: images/ISIC_0024508.png
#   Vector: [-0.01091168 -0.02055728 -0.04908438  0.04230993  0.01473207]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0024508.png
#     - images/ISIC_0024508_rotated_-13_brightness_1.03_flipped.png
#   Info transformaciones: images/ISIC_0024508_rotated_-13_brightness_1.03_flipped.png:rotated_-13, brightness_1.03, flipped
#   Otros metadatos: {'transformations_info': 'images/ISIC_0024508_rotated_-13_brightness_1.03_flipped.png:rotated_-13, brightness_1.03, flipped', 'associated_images': 'images/ISIC_0024508.png,images/ISIC_0024508_rotated_-13_brightness_1.03_flipped.png', 'image_type': 'original', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 3:
#   ID del registro: images/ISIC_0024853.png
#   Vector: [ 0.00449441  0.00574136 -0.01411529  0.01850141  0.0137807 ]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0024853.png
#     - images/ISIC_0024853_brightness_0.82_contrast_1.15_flipped.png
#   Info transformaciones: images/ISIC_0024853_brightness_0.82_contrast_1.15_flipped.png:brightness_0.82, contrast_1.15, flipped
#   Otros metadatos: {'image_type': 'original', 'associated_images': 'images/ISIC_0024853.png,images/ISIC_0024853_brightness_0.82_contrast_1.15_flipped.png', 'transformations_info': 'images/ISIC_0024853_brightness_0.82_contrast_1.15_flipped.png:brightness_0.82, contrast_1.15, flipped', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 4:
#   ID del registro: images/ISIC_0025118.png
#   Vector: [ 0.01125942 -0.00936773 -0.02758692  0.0212735   0.01231156]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0025118.png
#     - images/ISIC_0025118_brightness_1.19.png
#   Info transformaciones: images/ISIC_0025118_brightness_1.19.png:brightness_1.19
#   Otros metadatos: {'transformations_info': 'images/ISIC_0025118_brightness_1.19.png:brightness_1.19', 'type': 'original', 'image_type': 'original', 'associated_images': 'images/ISIC_0025118.png,images/ISIC_0025118_brightness_1.19.png'}
# --------------------------------------------------------------------------------
#
# Embedding 5:
#   ID del registro: images/ISIC_0025200.png
#   Vector: [ 0.00344155 -0.030877   -0.01998417  0.02646288  0.01467685]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0025200.png
#     - images/ISIC_0025200_rotated_-5_contrast_0.94.png
#   Info transformaciones: images/ISIC_0025200_rotated_-5_contrast_0.94.png:rotated_-5, contrast_0.94
#   Otros metadatos: {'type': 'original', 'transformations_info': 'images/ISIC_0025200_rotated_-5_contrast_0.94.png:rotated_-5, contrast_0.94', 'image_type': 'original', 'associated_images': 'images/ISIC_0025200.png,images/ISIC_0025200_rotated_-5_contrast_0.94.png'}
# --------------------------------------------------------------------------------
#
# Embedding 6:
#   ID del registro: images/ISIC_0025202.png
#   Vector: [ 0.02445663  0.00724421 -0.02728193  0.0364267   0.03225328]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0025202.png
#     - images/ISIC_0025202_rotated_2_contrast_0.96_flipped.png
#   Info transformaciones: images/ISIC_0025202_rotated_2_contrast_0.96_flipped.png:rotated_2, contrast_0.96, flipped
#   Otros metadatos: {'transformations_info': 'images/ISIC_0025202_rotated_2_contrast_0.96_flipped.png:rotated_2, contrast_0.96, flipped', 'associated_images': 'images/ISIC_0025202.png,images/ISIC_0025202_rotated_2_contrast_0.96_flipped.png', 'type': 'original', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 7:
#   ID del registro: images/ISIC_0025298.png
#   Vector: [ 0.01374584 -0.01879584 -0.03148149  0.0285682   0.00361107]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0025298.png
#     - images/ISIC_0025298_rotated_3_contrast_1.11.png
#   Info transformaciones: images/ISIC_0025298_rotated_3_contrast_1.11.png:rotated_3, contrast_1.11
#   Otros metadatos: {'image_type': 'original', 'associated_images': 'images/ISIC_0025298.png,images/ISIC_0025298_rotated_3_contrast_1.11.png', 'transformations_info': 'images/ISIC_0025298_rotated_3_contrast_1.11.png:rotated_3, contrast_1.11', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 8:
#   ID del registro: images/ISIC_0025343.png
#   Vector: [ 0.01280284 -0.02143798 -0.0403423   0.03259989  0.00867019]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0025343.png
#     - images/ISIC_0025343_flipped.png
#   Info transformaciones: images/ISIC_0025343_flipped.png:flipped
#   Otros metadatos: {'associated_images': 'images/ISIC_0025343.png,images/ISIC_0025343_flipped.png', 'type': 'original', 'image_type': 'original', 'transformations_info': 'images/ISIC_0025343_flipped.png:flipped'}
# --------------------------------------------------------------------------------
#
# Embedding 9:
#   ID del registro: images/ISIC_0025430.png
#   Vector: [ 0.00133812 -0.01886196 -0.04037132  0.03862811  0.02257077]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0025430.png
#     - images/ISIC_0025430_rotated_4_brightness_1.12_contrast_0.96.png
#   Info transformaciones: images/ISIC_0025430_rotated_4_brightness_1.12_contrast_0.96.png:rotated_4, brightness_1.12, contrast_0.96
#   Otros metadatos: {'type': 'original', 'image_type': 'original', 'associated_images': 'images/ISIC_0025430.png,images/ISIC_0025430_rotated_4_brightness_1.12_contrast_0.96.png', 'transformations_info': 'images/ISIC_0025430_rotated_4_brightness_1.12_contrast_0.96.png:rotated_4, brightness_1.12, contrast_0.96'}
# --------------------------------------------------------------------------------
#
# Embedding 10:
#   ID del registro: images/ISIC_0025806.png
#   Vector: [-0.0154553  -0.01123594 -0.03954926  0.04713185  0.01786992]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0025806.png
#     - images/ISIC_0025806_rotated_-4.png
#   Info transformaciones: images/ISIC_0025806_rotated_-4.png:rotated_-4
#   Otros metadatos: {'associated_images': 'images/ISIC_0025806.png,images/ISIC_0025806_rotated_-4.png', 'transformations_info': 'images/ISIC_0025806_rotated_-4.png:rotated_-4', 'type': 'original', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 11:
#   ID del registro: images/ISIC_0025874.png
#   Vector: [ 0.0127736   0.00149205 -0.01069783  0.0141592   0.01889801]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0025874.png
#     - images/ISIC_0025874_brightness_1.15_contrast_0.99.png
#   Info transformaciones: images/ISIC_0025874_brightness_1.15_contrast_0.99.png:brightness_1.15, contrast_0.99
#   Otros metadatos: {'transformations_info': 'images/ISIC_0025874_brightness_1.15_contrast_0.99.png:brightness_1.15, contrast_0.99', 'image_type': 'original', 'type': 'original', 'associated_images': 'images/ISIC_0025874.png,images/ISIC_0025874_brightness_1.15_contrast_0.99.png'}
# --------------------------------------------------------------------------------
#
# Embedding 12:
#   ID del registro: images/ISIC_0025886.png
#   Vector: [ 0.01317594 -0.01082373 -0.05005679  0.03517215  0.02201676]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0025886.png
#     - images/ISIC_0025886_rotated_-2_brightness_0.99.png
#   Info transformaciones: images/ISIC_0025886_rotated_-2_brightness_0.99.png:rotated_-2, brightness_0.99
#   Otros metadatos: {'image_type': 'original', 'type': 'original', 'transformations_info': 'images/ISIC_0025886_rotated_-2_brightness_0.99.png:rotated_-2, brightness_0.99', 'associated_images': 'images/ISIC_0025886.png,images/ISIC_0025886_rotated_-2_brightness_0.99.png'}
# --------------------------------------------------------------------------------
#
# Embedding 13:
#   ID del registro: images/ISIC_0025899.png
#   Vector: [ 0.01393954 -0.00300591 -0.010154    0.00699406  0.01209712]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0025899.png
#     - images/ISIC_0025899_contrast_1.15_flipped.png
#   Info transformaciones: images/ISIC_0025899_contrast_1.15_flipped.png:contrast_1.15, flipped
#   Otros metadatos: {'transformations_info': 'images/ISIC_0025899_contrast_1.15_flipped.png:contrast_1.15, flipped', 'associated_images': 'images/ISIC_0025899.png,images/ISIC_0025899_contrast_1.15_flipped.png', 'image_type': 'original', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 14:
#   ID del registro: images/ISIC_0025960.png
#   Vector: [ 0.01572194 -0.00879369 -0.00869887  0.00949537  0.00369583]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0025960.png
#     - images/ISIC_0025960_augmented.png
#   Info transformaciones: images/ISIC_0025960_augmented.png:none
#   Otros metadatos: {'associated_images': 'images/ISIC_0025960.png,images/ISIC_0025960_augmented.png', 'image_type': 'original', 'transformations_info': 'images/ISIC_0025960_augmented.png:none', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 15:
#   ID del registro: images/ISIC_0026077.png
#   Vector: [ 0.01854017 -0.01351146 -0.05295406  0.04876968 -0.01487969]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0026077.png
#     - images/ISIC_0026077_brightness_0.98_flipped.png
#   Info transformaciones: images/ISIC_0026077_brightness_0.98_flipped.png:brightness_0.98, flipped
#   Otros metadatos: {'image_type': 'original', 'transformations_info': 'images/ISIC_0026077_brightness_0.98_flipped.png:brightness_0.98, flipped', 'associated_images': 'images/ISIC_0026077.png,images/ISIC_0026077_brightness_0.98_flipped.png', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 16:
#   ID del registro: images/ISIC_0026128.png
#   Vector: [ 1.3351330e-03 -6.4717340e-05 -3.8560145e-02  2.4081085e-02
#   2.8792318e-02]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0026128.png
#     - images/ISIC_0026128_brightness_0.81_contrast_1.07_flipped.png
#   Info transformaciones: images/ISIC_0026128_brightness_0.81_contrast_1.07_flipped.png:brightness_0.81, contrast_1.07, flipped
#   Otros metadatos: {'associated_images': 'images/ISIC_0026128.png,images/ISIC_0026128_brightness_0.81_contrast_1.07_flipped.png', 'type': 'original', 'transformations_info': 'images/ISIC_0026128_brightness_0.81_contrast_1.07_flipped.png:brightness_0.81, contrast_1.07, flipped', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 17:
#   ID del registro: images/ISIC_0026152.png
#   Vector: [ 0.01217128 -0.00189536 -0.03640664  0.03415362  0.02888421]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0026152.png
#     - images/ISIC_0026152_rotated_1_flipped.png
#   Info transformaciones: images/ISIC_0026152_rotated_1_flipped.png:rotated_1, flipped
#   Otros metadatos: {'transformations_info': 'images/ISIC_0026152_rotated_1_flipped.png:rotated_1, flipped', 'image_type': 'original', 'type': 'original', 'associated_images': 'images/ISIC_0026152.png,images/ISIC_0026152_rotated_1_flipped.png'}
# --------------------------------------------------------------------------------
#
# Embedding 18:
#   ID del registro: images/ISIC_0026283.png
#   Vector: [ 0.02081151 -0.00115781 -0.0211343   0.03164659  0.01210109]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0026283.png
#     - images/ISIC_0026283_rotated_3_contrast_0.82.png
#   Info transformaciones: images/ISIC_0026283_rotated_3_contrast_0.82.png:rotated_3, contrast_0.82
#   Otros metadatos: {'type': 'original', 'associated_images': 'images/ISIC_0026283.png,images/ISIC_0026283_rotated_3_contrast_0.82.png', 'transformations_info': 'images/ISIC_0026283_rotated_3_contrast_0.82.png:rotated_3, contrast_0.82', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 19:
#   ID del registro: images/ISIC_0026289.png
#   Vector: [ 0.0169967  -0.00619648 -0.02775804  0.03161497  0.02273474]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0026289.png
#     - images/ISIC_0026289_contrast_0.93.png
#   Info transformaciones: images/ISIC_0026289_contrast_0.93.png:contrast_0.93
#   Otros metadatos: {'transformations_info': 'images/ISIC_0026289_contrast_0.93.png:contrast_0.93', 'image_type': 'original', 'associated_images': 'images/ISIC_0026289.png,images/ISIC_0026289_contrast_0.93.png', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 20:
#   ID del registro: images/ISIC_0026507.png
#   Vector: [ 0.00308528 -0.0213203  -0.03801672  0.00335722  0.02383137]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0026507.png
#     - images/ISIC_0026507_rotated_12_brightness_1.08_flipped.png
#   Info transformaciones: images/ISIC_0026507_rotated_12_brightness_1.08_flipped.png:rotated_12, brightness_1.08, flipped
#   Otros metadatos: {'associated_images': 'images/ISIC_0026507.png,images/ISIC_0026507_rotated_12_brightness_1.08_flipped.png', 'type': 'original', 'transformations_info': 'images/ISIC_0026507_rotated_12_brightness_1.08_flipped.png:rotated_12, brightness_1.08, flipped', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 21:
#   ID del registro: images/ISIC_0026653.png
#   Vector: [ 0.00549644  0.00012924 -0.00913825  0.01207577  0.00627354]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0026653.png
#     - images/ISIC_0026653_brightness_0.95.png
#   Info transformaciones: images/ISIC_0026653_brightness_0.95.png:brightness_0.95
#   Otros metadatos: {'transformations_info': 'images/ISIC_0026653_brightness_0.95.png:brightness_0.95', 'image_type': 'original', 'associated_images': 'images/ISIC_0026653.png,images/ISIC_0026653_brightness_0.95.png', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 22:
#   ID del registro: images/ISIC_0026710.png
#   Vector: [ 0.01763856 -0.00487728 -0.03017028  0.02215402  0.03055992]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0026710.png
#     - images/ISIC_0026710_augmented.png
#   Info transformaciones: images/ISIC_0026710_augmented.png:none
#   Otros metadatos: {'transformations_info': 'images/ISIC_0026710_augmented.png:none', 'associated_images': 'images/ISIC_0026710.png,images/ISIC_0026710_augmented.png', 'image_type': 'original', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 23:
#   ID del registro: images/ISIC_0026803.png
#   Vector: [ 0.02363533  0.00771739 -0.01284052  0.02143278  0.02362205]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0026803.png
#     - images/ISIC_0026803_brightness_1.01_contrast_0.92_flipped.png
#   Info transformaciones: images/ISIC_0026803_brightness_1.01_contrast_0.92_flipped.png:brightness_1.01, contrast_0.92, flipped
#   Otros metadatos: {'transformations_info': 'images/ISIC_0026803_brightness_1.01_contrast_0.92_flipped.png:brightness_1.01, contrast_0.92, flipped', 'associated_images': 'images/ISIC_0026803.png,images/ISIC_0026803_brightness_1.01_contrast_0.92_flipped.png', 'image_type': 'original', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 24:
#   ID del registro: images/ISIC_0026911.png
#   Vector: [ 0.01677191 -0.00050146 -0.00777636  0.02543087  0.03239663]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0026911.png
#     - images/ISIC_0026911_rotated_-1_flipped.png
#   Info transformaciones: images/ISIC_0026911_rotated_-1_flipped.png:rotated_-1, flipped
#   Otros metadatos: {'associated_images': 'images/ISIC_0026911.png,images/ISIC_0026911_rotated_-1_flipped.png', 'image_type': 'original', 'transformations_info': 'images/ISIC_0026911_rotated_-1_flipped.png:rotated_-1, flipped', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 25:
#   ID del registro: images/ISIC_0027058.png
#   Vector: [ 0.00515188  0.00259425 -0.01882192  0.03826836  0.00833906]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0027058.png
#     - images/ISIC_0027058_flipped.png
#   Info transformaciones: images/ISIC_0027058_flipped.png:flipped
#   Otros metadatos: {'associated_images': 'images/ISIC_0027058.png,images/ISIC_0027058_flipped.png', 'transformations_info': 'images/ISIC_0027058_flipped.png:flipped', 'image_type': 'original', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 26:
#   ID del registro: images/ISIC_0027077.png
#   Vector: [ 0.02390236 -0.00101899 -0.01779498  0.00880341  0.02474648]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0027077.png
#     - images/ISIC_0027077_rotated_0_contrast_1.09_flipped.png
#   Info transformaciones: images/ISIC_0027077_rotated_0_contrast_1.09_flipped.png:rotated_0, contrast_1.09, flipped
#   Otros metadatos: {'associated_images': 'images/ISIC_0027077.png,images/ISIC_0027077_rotated_0_contrast_1.09_flipped.png', 'transformations_info': 'images/ISIC_0027077_rotated_0_contrast_1.09_flipped.png:rotated_0, contrast_1.09, flipped', 'type': 'original', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 27:
#   ID del registro: images/ISIC_0027209.png
#   Vector: [ 0.01588157 -0.00628285 -0.02420168  0.00308543  0.02197479]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0027209.png
#     - images/ISIC_0027209_rotated_4_flipped.png
#   Info transformaciones: images/ISIC_0027209_rotated_4_flipped.png:rotated_4, flipped
#   Otros metadatos: {'type': 'original', 'image_type': 'original', 'associated_images': 'images/ISIC_0027209.png,images/ISIC_0027209_rotated_4_flipped.png', 'transformations_info': 'images/ISIC_0027209_rotated_4_flipped.png:rotated_4, flipped'}
# --------------------------------------------------------------------------------
#
# Embedding 28:
#   ID del registro: images/ISIC_0027219.png
#   Vector: [ 0.04260688  0.00079807 -0.02911308  0.02631747  0.012279  ]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0027219.png
#     - images/ISIC_0027219_rotated_11.png
#   Info transformaciones: images/ISIC_0027219_rotated_11.png:rotated_11
#   Otros metadatos: {'type': 'original', 'associated_images': 'images/ISIC_0027219.png,images/ISIC_0027219_rotated_11.png', 'transformations_info': 'images/ISIC_0027219_rotated_11.png:rotated_11', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 29:
#   ID del registro: images/ISIC_0027249.png
#   Vector: [ 0.0182446  -0.0015127  -0.00114403  0.01905669  0.0287117 ]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0027249.png
#     - images/ISIC_0027249_rotated_-12_contrast_1.10.png
#   Info transformaciones: images/ISIC_0027249_rotated_-12_contrast_1.10.png:rotated_-12, contrast_1.10
#   Otros metadatos: {'transformations_info': 'images/ISIC_0027249_rotated_-12_contrast_1.10.png:rotated_-12, contrast_1.10', 'type': 'original', 'image_type': 'original', 'associated_images': 'images/ISIC_0027249.png,images/ISIC_0027249_rotated_-12_contrast_1.10.png'}
# --------------------------------------------------------------------------------
#
# Embedding 30:
#   ID del registro: images/ISIC_0027307.png
#   Vector: [ 0.01699191  0.00592696 -0.02818497  0.01493816  0.02641014]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0027307.png
#     - images/ISIC_0027307_rotated_5_brightness_0.81.png
#   Info transformaciones: images/ISIC_0027307_rotated_5_brightness_0.81.png:rotated_5, brightness_0.81
#   Otros metadatos: {'transformations_info': 'images/ISIC_0027307_rotated_5_brightness_0.81.png:rotated_5, brightness_0.81', 'type': 'original', 'image_type': 'original', 'associated_images': 'images/ISIC_0027307.png,images/ISIC_0027307_rotated_5_brightness_0.81.png'}
# --------------------------------------------------------------------------------
#
# Embedding 31:
#   ID del registro: images/ISIC_0027620.png
#   Vector: [ 0.0186013  -0.00670073 -0.00948957  0.00939863  0.02056485]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0027620.png
#     - images/ISIC_0027620_rotated_9.png
#   Info transformaciones: images/ISIC_0027620_rotated_9.png:rotated_9
#   Otros metadatos: {'associated_images': 'images/ISIC_0027620.png,images/ISIC_0027620_rotated_9.png', 'image_type': 'original', 'transformations_info': 'images/ISIC_0027620_rotated_9.png:rotated_9', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 32:
#   ID del registro: images/ISIC_0027710.png
#   Vector: [ 0.03252639 -0.01369929 -0.02540692  0.01638038  0.03534392]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0027710.png
#     - images/ISIC_0027710_rotated_4_brightness_0.83_contrast_1.10_flipped.png
#   Info transformaciones: images/ISIC_0027710_rotated_4_brightness_0.83_contrast_1.10_flipped.png:rotated_4, brightness_0.83, contrast_1.10, flipped
#   Otros metadatos: {'type': 'original', 'image_type': 'original', 'transformations_info': 'images/ISIC_0027710_rotated_4_brightness_0.83_contrast_1.10_flipped.png:rotated_4, brightness_0.83, contrast_1.10, flipped', 'associated_images': 'images/ISIC_0027710.png,images/ISIC_0027710_rotated_4_brightness_0.83_contrast_1.10_flipped.png'}
# --------------------------------------------------------------------------------
#
# Embedding 33:
#   ID del registro: images/ISIC_0027841.png
#   Vector: [ 0.01318089  0.00972903 -0.04053685  0.04536879  0.01465679]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0027841.png
#     - images/ISIC_0027841_rotated_13_flipped.png
#   Info transformaciones: images/ISIC_0027841_rotated_13_flipped.png:rotated_13, flipped
#   Otros metadatos: {'transformations_info': 'images/ISIC_0027841_rotated_13_flipped.png:rotated_13, flipped', 'type': 'original', 'associated_images': 'images/ISIC_0027841.png,images/ISIC_0027841_rotated_13_flipped.png', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 34:
#   ID del registro: images/ISIC_0027999.png
#   Vector: [ 0.02496729 -0.0065368  -0.02490858  0.008245    0.01651797]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0027999.png
#     - images/ISIC_0027999_augmented.png
#   Info transformaciones: images/ISIC_0027999_augmented.png:none
#   Otros metadatos: {'type': 'original', 'transformations_info': 'images/ISIC_0027999_augmented.png:none', 'associated_images': 'images/ISIC_0027999.png,images/ISIC_0027999_augmented.png', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 35:
#   ID del registro: images/ISIC_0028025.png
#   Vector: [ 0.00694997 -0.01404682 -0.02731946  0.03250327  0.01721273]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0028025.png
#     - images/ISIC_0028025_brightness_0.86_contrast_1.03_flipped.png
#   Info transformaciones: images/ISIC_0028025_brightness_0.86_contrast_1.03_flipped.png:brightness_0.86, contrast_1.03, flipped
#   Otros metadatos: {'type': 'original', 'transformations_info': 'images/ISIC_0028025_brightness_0.86_contrast_1.03_flipped.png:brightness_0.86, contrast_1.03, flipped', 'associated_images': 'images/ISIC_0028025.png,images/ISIC_0028025_brightness_0.86_contrast_1.03_flipped.png', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 36:
#   ID del registro: images/ISIC_0028103.png
#   Vector: [ 0.01175773  0.01532797 -0.01899275  0.01669494 -0.00077613]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0028103.png
#     - images/ISIC_0028103_rotated_4_brightness_1.08_flipped.png
#   Info transformaciones: images/ISIC_0028103_rotated_4_brightness_1.08_flipped.png:rotated_4, brightness_1.08, flipped
#   Otros metadatos: {'associated_images': 'images/ISIC_0028103.png,images/ISIC_0028103_rotated_4_brightness_1.08_flipped.png', 'image_type': 'original', 'type': 'original', 'transformations_info': 'images/ISIC_0028103_rotated_4_brightness_1.08_flipped.png:rotated_4, brightness_1.08, flipped'}
# --------------------------------------------------------------------------------
#
# Embedding 37:
#   ID del registro: images/ISIC_0028175.png
#   Vector: [ 0.02134456 -0.01377021 -0.032189    0.0483725   0.0167377 ]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0028175.png
#     - images/ISIC_0028175_contrast_0.85.png
#   Info transformaciones: images/ISIC_0028175_contrast_0.85.png:contrast_0.85
#   Otros metadatos: {'type': 'original', 'image_type': 'original', 'associated_images': 'images/ISIC_0028175.png,images/ISIC_0028175_contrast_0.85.png', 'transformations_info': 'images/ISIC_0028175_contrast_0.85.png:contrast_0.85'}
# --------------------------------------------------------------------------------
#
# Embedding 38:
#   ID del registro: images/ISIC_0028280.png
#   Vector: [ 0.03802249 -0.00509653 -0.01587542  0.03295568  0.01249744]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0028280.png
#     - images/ISIC_0028280_rotated_7_brightness_0.96_contrast_0.92.png
#   Info transformaciones: images/ISIC_0028280_rotated_7_brightness_0.96_contrast_0.92.png:rotated_7, brightness_0.96, contrast_0.92
#   Otros metadatos: {'transformations_info': 'images/ISIC_0028280_rotated_7_brightness_0.96_contrast_0.92.png:rotated_7, brightness_0.96, contrast_0.92', 'image_type': 'original', 'associated_images': 'images/ISIC_0028280.png,images/ISIC_0028280_rotated_7_brightness_0.96_contrast_0.92.png', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 39:
#   ID del registro: images/ISIC_0028381.png
#   Vector: [ 0.02123318 -0.01242245 -0.02104927  0.00624634  0.02476739]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0028381.png
#     - images/ISIC_0028381_rotated_1_brightness_0.83_flipped.png
#   Info transformaciones: images/ISIC_0028381_rotated_1_brightness_0.83_flipped.png:rotated_1, brightness_0.83, flipped
#   Otros metadatos: {'associated_images': 'images/ISIC_0028381.png,images/ISIC_0028381_rotated_1_brightness_0.83_flipped.png', 'transformations_info': 'images/ISIC_0028381_rotated_1_brightness_0.83_flipped.png:rotated_1, brightness_0.83, flipped', 'type': 'original', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 40:
#   ID del registro: images/ISIC_0028416.png
#   Vector: [ 0.02456519 -0.01241321 -0.01480728  0.02247219  0.02908975]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0028416.png
#     - images/ISIC_0028416_rotated_11_brightness_0.93_contrast_1.12_flipped.png
#   Info transformaciones: images/ISIC_0028416_rotated_11_brightness_0.93_contrast_1.12_flipped.png:rotated_11, brightness_0.93, contrast_1.12, flipped
#   Otros metadatos: {'type': 'original', 'transformations_info': 'images/ISIC_0028416_rotated_11_brightness_0.93_contrast_1.12_flipped.png:rotated_11, brightness_0.93, contrast_1.12, flipped', 'image_type': 'original', 'associated_images': 'images/ISIC_0028416.png,images/ISIC_0028416_rotated_11_brightness_0.93_contrast_1.12_flipped.png'}
# --------------------------------------------------------------------------------
#
# Embedding 41:
#   ID del registro: images/ISIC_0028726.png
#   Vector: [ 0.00189383 -0.01283241 -0.0054169   0.03762672  0.02429997]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0028726.png
#     - images/ISIC_0028726_rotated_-11_brightness_0.95_flipped.png
#   Info transformaciones: images/ISIC_0028726_rotated_-11_brightness_0.95_flipped.png:rotated_-11, brightness_0.95, flipped
#   Otros metadatos: {'transformations_info': 'images/ISIC_0028726_rotated_-11_brightness_0.95_flipped.png:rotated_-11, brightness_0.95, flipped', 'image_type': 'original', 'associated_images': 'images/ISIC_0028726.png,images/ISIC_0028726_rotated_-11_brightness_0.95_flipped.png', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 42:
#   ID del registro: images/ISIC_0028948.png
#   Vector: [ 0.02947219 -0.00918802 -0.01968661  0.02618798  0.02938912]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0028948.png
#     - images/ISIC_0028948_contrast_0.94_flipped.png
#   Info transformaciones: images/ISIC_0028948_contrast_0.94_flipped.png:contrast_0.94, flipped
#   Otros metadatos: {'image_type': 'original', 'type': 'original', 'associated_images': 'images/ISIC_0028948.png,images/ISIC_0028948_contrast_0.94_flipped.png', 'transformations_info': 'images/ISIC_0028948_contrast_0.94_flipped.png:contrast_0.94, flipped'}
# --------------------------------------------------------------------------------
#
# Embedding 43:
#   ID del registro: images/ISIC_0029024.png
#   Vector: [ 0.01495899 -0.00964392 -0.01459762  0.04277553  0.0126628 ]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0029024.png
#     - images/ISIC_0029024_rotated_-5_contrast_1.17.png
#   Info transformaciones: images/ISIC_0029024_rotated_-5_contrast_1.17.png:rotated_-5, contrast_1.17
#   Otros metadatos: {'image_type': 'original', 'type': 'original', 'associated_images': 'images/ISIC_0029024.png,images/ISIC_0029024_rotated_-5_contrast_1.17.png', 'transformations_info': 'images/ISIC_0029024_rotated_-5_contrast_1.17.png:rotated_-5, contrast_1.17'}
# --------------------------------------------------------------------------------
#
# Embedding 44:
#   ID del registro: images/ISIC_0029220.png
#   Vector: [ 0.00753813 -0.00493855 -0.00908423  0.02196785  0.02777001]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0029220.png
#     - images/ISIC_0029220_rotated_5_flipped.png
#   Info transformaciones: images/ISIC_0029220_rotated_5_flipped.png:rotated_5, flipped
#   Otros metadatos: {'associated_images': 'images/ISIC_0029220.png,images/ISIC_0029220_rotated_5_flipped.png', 'transformations_info': 'images/ISIC_0029220_rotated_5_flipped.png:rotated_5, flipped', 'type': 'original', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 45:
#   ID del registro: images/ISIC_0029263.png
#   Vector: [ 8.2252810e-03  3.5357232e-05 -4.8124865e-03 -7.5221527e-03
#  -9.1204260e-03]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0029263.png
#     - images/ISIC_0029263_rotated_-12_contrast_1.17_flipped.png
#   Info transformaciones: images/ISIC_0029263_rotated_-12_contrast_1.17_flipped.png:rotated_-12, contrast_1.17, flipped
#   Otros metadatos: {'image_type': 'original', 'transformations_info': 'images/ISIC_0029263_rotated_-12_contrast_1.17_flipped.png:rotated_-12, contrast_1.17, flipped', 'type': 'original', 'associated_images': 'images/ISIC_0029263.png,images/ISIC_0029263_rotated_-12_contrast_1.17_flipped.png'}
# --------------------------------------------------------------------------------
#
# Embedding 46:
#   ID del registro: images/ISIC_0029475.png
#   Vector: [ 2.1412686e-02  2.1090347e-05 -2.1682028e-02  3.3635604e-03
#   4.1777864e-03]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0029475.png
#     - images/ISIC_0029475_rotated_15_brightness_1.01_contrast_1.03.png
#   Info transformaciones: images/ISIC_0029475_rotated_15_brightness_1.01_contrast_1.03.png:rotated_15, brightness_1.01, contrast_1.03
#   Otros metadatos: {'image_type': 'original', 'type': 'original', 'transformations_info': 'images/ISIC_0029475_rotated_15_brightness_1.01_contrast_1.03.png:rotated_15, brightness_1.01, contrast_1.03', 'associated_images': 'images/ISIC_0029475.png,images/ISIC_0029475_rotated_15_brightness_1.01_contrast_1.03.png'}
# --------------------------------------------------------------------------------
#
# Embedding 47:
#   ID del registro: images/ISIC_0029577.png
#   Vector: [ 0.01000569 -0.00626472 -0.01028662  0.01742344  0.02143859]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0029577.png
#     - images/ISIC_0029577_brightness_1.00_flipped.png
#   Info transformaciones: images/ISIC_0029577_brightness_1.00_flipped.png:brightness_1.00, flipped
#   Otros metadatos: {'type': 'original', 'image_type': 'original', 'associated_images': 'images/ISIC_0029577.png,images/ISIC_0029577_brightness_1.00_flipped.png', 'transformations_info': 'images/ISIC_0029577_brightness_1.00_flipped.png:brightness_1.00, flipped'}
# --------------------------------------------------------------------------------
#
# Embedding 48:
#   ID del registro: images/ISIC_0029623.png
#   Vector: [-0.02008211  0.00121557 -0.0462766   0.0278461   0.01989276]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0029623.png
#     - images/ISIC_0029623_brightness_1.09_contrast_1.00.png
#   Info transformaciones: images/ISIC_0029623_brightness_1.09_contrast_1.00.png:brightness_1.09, contrast_1.00
#   Otros metadatos: {'type': 'original', 'image_type': 'original', 'transformations_info': 'images/ISIC_0029623_brightness_1.09_contrast_1.00.png:brightness_1.09, contrast_1.00', 'associated_images': 'images/ISIC_0029623.png,images/ISIC_0029623_brightness_1.09_contrast_1.00.png'}
# --------------------------------------------------------------------------------
#
# Embedding 49:
#   ID del registro: images/ISIC_0029649.png
#   Vector: [ 0.02471597  0.00227088 -0.00860027  0.02903089  0.01550372]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0029649.png
#     - images/ISIC_0029649_rotated_0_brightness_0.96_contrast_1.09.png
#   Info transformaciones: images/ISIC_0029649_rotated_0_brightness_0.96_contrast_1.09.png:rotated_0, brightness_0.96, contrast_1.09
#   Otros metadatos: {'type': 'original', 'associated_images': 'images/ISIC_0029649.png,images/ISIC_0029649_rotated_0_brightness_0.96_contrast_1.09.png', 'image_type': 'original', 'transformations_info': 'images/ISIC_0029649_rotated_0_brightness_0.96_contrast_1.09.png:rotated_0, brightness_0.96, contrast_1.09'}
# --------------------------------------------------------------------------------
#
# Embedding 50:
#   ID del registro: images/ISIC_0029694.png
#   Vector: [-0.01433282 -0.01553226 -0.02237825  0.03944887  0.00743286]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0029694.png
#     - images/ISIC_0029694_rotated_9_flipped.png
#   Info transformaciones: images/ISIC_0029694_rotated_9_flipped.png:rotated_9, flipped
#   Otros metadatos: {'image_type': 'original', 'type': 'original', 'associated_images': 'images/ISIC_0029694.png,images/ISIC_0029694_rotated_9_flipped.png', 'transformations_info': 'images/ISIC_0029694_rotated_9_flipped.png:rotated_9, flipped'}
# --------------------------------------------------------------------------------
#
# Embedding 51:
#   ID del registro: images/ISIC_0029834.png
#   Vector: [ 0.01694005 -0.01102383 -0.01961614  0.04080529  0.02083127]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0029834.png
#     - images/ISIC_0029834_rotated_-14.png
#   Info transformaciones: images/ISIC_0029834_rotated_-14.png:rotated_-14
#   Otros metadatos: {'type': 'original', 'transformations_info': 'images/ISIC_0029834_rotated_-14.png:rotated_-14', 'image_type': 'original', 'associated_images': 'images/ISIC_0029834.png,images/ISIC_0029834_rotated_-14.png'}
# --------------------------------------------------------------------------------
#
# Embedding 52:
#   ID del registro: images/ISIC_0029851.png
#   Vector: [-0.00196411 -0.00774993 -0.00320553 -0.00198832 -0.01349081]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0029851.png
#     - images/ISIC_0029851_rotated_-9_brightness_1.15_contrast_0.82_flipped.png
#   Info transformaciones: images/ISIC_0029851_rotated_-9_brightness_1.15_contrast_0.82_flipped.png:rotated_-9, brightness_1.15, contrast_0.82, flipped
#   Otros metadatos: {'image_type': 'original', 'type': 'original', 'associated_images': 'images/ISIC_0029851.png,images/ISIC_0029851_rotated_-9_brightness_1.15_contrast_0.82_flipped.png', 'transformations_info': 'images/ISIC_0029851_rotated_-9_brightness_1.15_contrast_0.82_flipped.png:rotated_-9, brightness_1.15, contrast_0.82, flipped'}
# --------------------------------------------------------------------------------
#
# Embedding 53:
#   ID del registro: images/ISIC_0029876.png
#   Vector: [ 0.02997167 -0.00345055 -0.01921082  0.02212277  0.02241677]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0029876.png
#     - images/ISIC_0029876_rotated_-15_brightness_0.95_flipped.png
#   Info transformaciones: images/ISIC_0029876_rotated_-15_brightness_0.95_flipped.png:rotated_-15, brightness_0.95, flipped
#   Otros metadatos: {'type': 'original', 'transformations_info': 'images/ISIC_0029876_rotated_-15_brightness_0.95_flipped.png:rotated_-15, brightness_0.95, flipped', 'image_type': 'original', 'associated_images': 'images/ISIC_0029876.png,images/ISIC_0029876_rotated_-15_brightness_0.95_flipped.png'}
# --------------------------------------------------------------------------------
#
# Embedding 54:
#   ID del registro: images/ISIC_0029896.png
#   Vector: [ 0.02036635  0.00269524 -0.00724164  0.02480619  0.0149514 ]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0029896.png
#     - images/ISIC_0029896_brightness_0.91_flipped.png
#   Info transformaciones: images/ISIC_0029896_brightness_0.91_flipped.png:brightness_0.91, flipped
#   Otros metadatos: {'image_type': 'original', 'transformations_info': 'images/ISIC_0029896_brightness_0.91_flipped.png:brightness_0.91, flipped', 'type': 'original', 'associated_images': 'images/ISIC_0029896.png,images/ISIC_0029896_brightness_0.91_flipped.png'}
# --------------------------------------------------------------------------------
#
# Embedding 55:
#   ID del registro: images/ISIC_0029929.png
#   Vector: [-0.01848452 -0.00058775  0.00345549  0.01731116 -0.00907827]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0029929.png
#     - images/ISIC_0029929_brightness_1.02_contrast_0.90_flipped.png
#   Info transformaciones: images/ISIC_0029929_brightness_1.02_contrast_0.90_flipped.png:brightness_1.02, contrast_0.90, flipped
#   Otros metadatos: {'type': 'original', 'image_type': 'original', 'transformations_info': 'images/ISIC_0029929_brightness_1.02_contrast_0.90_flipped.png:brightness_1.02, contrast_0.90, flipped', 'associated_images': 'images/ISIC_0029929.png,images/ISIC_0029929_brightness_1.02_contrast_0.90_flipped.png'}
# --------------------------------------------------------------------------------
#
# Embedding 56:
#   ID del registro: images/ISIC_0030055.png
#   Vector: [-0.02568738 -0.01163389 -0.04184473  0.03440484  0.02538315]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0030055.png
#     - images/ISIC_0030055_rotated_3_contrast_0.88_flipped.png
#   Info transformaciones: images/ISIC_0030055_rotated_3_contrast_0.88_flipped.png:rotated_3, contrast_0.88, flipped
#   Otros metadatos: {'associated_images': 'images/ISIC_0030055.png,images/ISIC_0030055_rotated_3_contrast_0.88_flipped.png', 'transformations_info': 'images/ISIC_0030055_rotated_3_contrast_0.88_flipped.png:rotated_3, contrast_0.88, flipped', 'image_type': 'original', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 57:
#   ID del registro: images/ISIC_0030197.png
#   Vector: [-0.00354442 -0.00551159 -0.02661058  0.03213561  0.00099803]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0030197.png
#     - images/ISIC_0030197_augmented.png
#   Info transformaciones: images/ISIC_0030197_augmented.png:none
#   Otros metadatos: {'associated_images': 'images/ISIC_0030197.png,images/ISIC_0030197_augmented.png', 'transformations_info': 'images/ISIC_0030197_augmented.png:none', 'image_type': 'original', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 58:
#   ID del registro: images/ISIC_0030269.png
#   Vector: [ 0.01595645 -0.00933474 -0.01440552  0.01815461  0.01576128]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0030269.png
#     - images/ISIC_0030269_contrast_0.92_flipped.png
#   Info transformaciones: images/ISIC_0030269_contrast_0.92_flipped.png:contrast_0.92, flipped
#   Otros metadatos: {'associated_images': 'images/ISIC_0030269.png,images/ISIC_0030269_contrast_0.92_flipped.png', 'image_type': 'original', 'transformations_info': 'images/ISIC_0030269_contrast_0.92_flipped.png:contrast_0.92, flipped', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 59:
#   ID del registro: images/ISIC_0030297.png
#   Vector: [-0.00217325  0.00569339 -0.01507764  0.02366368  0.01927417]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0030297.png
#     - images/ISIC_0030297_rotated_-12_contrast_0.98.png
#   Info transformaciones: images/ISIC_0030297_rotated_-12_contrast_0.98.png:rotated_-12, contrast_0.98
#   Otros metadatos: {'associated_images': 'images/ISIC_0030297.png,images/ISIC_0030297_rotated_-12_contrast_0.98.png', 'image_type': 'original', 'transformations_info': 'images/ISIC_0030297_rotated_-12_contrast_0.98.png:rotated_-12, contrast_0.98', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 60:
#   ID del registro: images/ISIC_0030397.png
#   Vector: [ 0.0351996  -0.00190885 -0.01139083  0.03411646  0.02433438]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0030397.png
#     - images/ISIC_0030397_contrast_1.01_flipped.png
#   Info transformaciones: images/ISIC_0030397_contrast_1.01_flipped.png:contrast_1.01, flipped
#   Otros metadatos: {'associated_images': 'images/ISIC_0030397.png,images/ISIC_0030397_contrast_1.01_flipped.png', 'image_type': 'original', 'type': 'original', 'transformations_info': 'images/ISIC_0030397_contrast_1.01_flipped.png:contrast_1.01, flipped'}
# --------------------------------------------------------------------------------
#
# Embedding 61:
#   ID del registro: images/ISIC_0030413.png
#   Vector: [ 0.00478846 -0.01809259 -0.02284605  0.03024457  0.01995391]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0030413.png
#     - images/ISIC_0030413_rotated_-1_brightness_1.10_contrast_1.19.png
#   Info transformaciones: images/ISIC_0030413_rotated_-1_brightness_1.10_contrast_1.19.png:rotated_-1, brightness_1.10, contrast_1.19
#   Otros metadatos: {'type': 'original', 'transformations_info': 'images/ISIC_0030413_rotated_-1_brightness_1.10_contrast_1.19.png:rotated_-1, brightness_1.10, contrast_1.19', 'associated_images': 'images/ISIC_0030413.png,images/ISIC_0030413_rotated_-1_brightness_1.10_contrast_1.19.png', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 62:
#   ID del registro: images/ISIC_0030421.png
#   Vector: [ 0.01250534  0.0023085  -0.00865806  0.02127539  0.02768262]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0030421.png
#     - images/ISIC_0030421_rotated_3_brightness_1.02_contrast_0.96.png
#   Info transformaciones: images/ISIC_0030421_rotated_3_brightness_1.02_contrast_0.96.png:rotated_3, brightness_1.02, contrast_0.96
#   Otros metadatos: {'transformations_info': 'images/ISIC_0030421_rotated_3_brightness_1.02_contrast_0.96.png:rotated_3, brightness_1.02, contrast_0.96', 'image_type': 'original', 'associated_images': 'images/ISIC_0030421.png,images/ISIC_0030421_rotated_3_brightness_1.02_contrast_0.96.png', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 63:
#   ID del registro: images/ISIC_0030492.png
#   Vector: [ 0.02519039 -0.01236645 -0.01297046  0.01038481  0.00146877]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0030492.png
#     - images/ISIC_0030492_brightness_0.97_contrast_0.96_flipped.png
#   Info transformaciones: images/ISIC_0030492_brightness_0.97_contrast_0.96_flipped.png:brightness_0.97, contrast_0.96, flipped
#   Otros metadatos: {'image_type': 'original', 'associated_images': 'images/ISIC_0030492.png,images/ISIC_0030492_brightness_0.97_contrast_0.96_flipped.png', 'transformations_info': 'images/ISIC_0030492_brightness_0.97_contrast_0.96_flipped.png:brightness_0.97, contrast_0.96, flipped', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 64:
#   ID del registro: images/ISIC_0030541.png
#   Vector: [ 0.02033612 -0.01682206 -0.03807076  0.01606102  0.01126429]... (primeros 5 valores)
#   Total de imágenes asociadas: 2
#   Imágenes asociadas:
#     - images/ISIC_0030541.png
#     - images/ISIC_0030541_rotated_-6_brightness_1.18_flipped.png
#   Info transformaciones: images/ISIC_0030541_rotated_-6_brightness_1.18_flipped.png:rotated_-6, brightness_1.18, flipped
# ...
# --------------------------------------------------------------------------------
#
# Embedding 228:
#   ID del registro: images/ISIC_0031655_augmented.png
#   Vector: [ 0.01371433 -0.01285532 -0.04117666  0.02519301 -0.00793396]... (primeros 5 valores)
#   Imagen: images/ISIC_0031655_augmented.png
#   Otros metadatos: {'original_image': 'images/ISIC_0031655.png', 'type': 'transformed', 'image_type': 'augmented', 'transformations': 'none'}
# --------------------------------------------------------------------------------
#
# Embedding 229:
#   ID del registro: images/ISIC_0031831_rotated_13_brightness_1.19_flipped.png
#   Vector: [ 0.03340527 -0.00382861 -0.02610197  0.02018058 -0.01241183]... (primeros 5 valores)
#   Imagen: images/ISIC_0031831_rotated_13_brightness_1.19_flipped.png
#   Otros metadatos: {'original_image': 'images/ISIC_0031831.png', 'type': 'transformed', 'transformations': 'rotated_13, brightness_1.19, flipped', 'image_type': 'augmented'}
# --------------------------------------------------------------------------------
#
# Embedding 230:
#   ID del registro: images/ISIC_0031948_rotated_4_brightness_0.89_contrast_0.83.png
#   Vector: [ 0.03172883 -0.01720192 -0.00512559  0.01451804  0.03257167]... (primeros 5 valores)
#   Imagen: images/ISIC_0031948_rotated_4_brightness_0.89_contrast_0.83.png
#   Otros metadatos: {'type': 'transformed', 'image_type': 'augmented', 'transformations': 'rotated_4, brightness_0.89, contrast_0.83', 'original_image': 'images/ISIC_0031948.png'}
# --------------------------------------------------------------------------------
#
# Embedding 231:
#   ID del registro: images/ISIC_0031981_brightness_0.86.png
#   Vector: [ 0.00027344 -0.00470603 -0.02586965  0.02464155  0.01238644]... (primeros 5 valores)
#   Imagen: images/ISIC_0031981_brightness_0.86.png
#   Otros metadatos: {'image_type': 'augmented', 'type': 'transformed', 'transformations': 'brightness_0.86', 'original_image': 'images/ISIC_0031981.png'}
# --------------------------------------------------------------------------------
#
# Embedding 232:
#   ID del registro: images/ISIC_0031987_rotated_15_contrast_1.07_flipped.png
#   Vector: [ 0.01068132  0.00234158 -0.00889558  0.02337731  0.02934256]... (primeros 5 valores)
#   Imagen: images/ISIC_0031987_rotated_15_contrast_1.07_flipped.png
#   Otros metadatos: {'original_image': 'images/ISIC_0031987.png', 'type': 'transformed', 'transformations': 'rotated_15, contrast_1.07, flipped', 'image_type': 'augmented'}
# --------------------------------------------------------------------------------
#
# Embedding 233:
#   ID del registro: images/ISIC_0032000_contrast_1.15_flipped.png
#   Vector: [-0.02407902 -0.00352176 -0.02104735  0.01874222  0.03560856]... (primeros 5 valores)
#   Imagen: images/ISIC_0032000_contrast_1.15_flipped.png
#   Otros metadatos: {'image_type': 'augmented', 'type': 'transformed', 'original_image': 'images/ISIC_0032000.png', 'transformations': 'contrast_1.15, flipped'}
# --------------------------------------------------------------------------------
#
# Embedding 234:
#   ID del registro: images/ISIC_0032110_rotated_-8_brightness_1.19_contrast_1.02.png
#   Vector: [ 0.02113677 -0.01455465 -0.00662071  0.00316786  0.01205785]... (primeros 5 valores)
#   Imagen: images/ISIC_0032110_rotated_-8_brightness_1.19_contrast_1.02.png
#   Otros metadatos: {'transformations': 'rotated_-8, brightness_1.19, contrast_1.02', 'original_image': 'images/ISIC_0032110.png', 'image_type': 'augmented', 'type': 'transformed'}
# --------------------------------------------------------------------------------
#
# Embedding 235:
#   ID del registro: images/ISIC_0032150_brightness_0.86_contrast_0.89_flipped.png
#   Vector: [ 0.03425972 -0.00111171 -0.01417503  0.02081074  0.0195289 ]... (primeros 5 valores)
#   Imagen: images/ISIC_0032150_brightness_0.86_contrast_0.89_flipped.png
#   Otros metadatos: {'type': 'transformed', 'original_image': 'images/ISIC_0032150.png', 'transformations': 'brightness_0.86, contrast_0.89, flipped', 'image_type': 'augmented'}
# --------------------------------------------------------------------------------
#
# Embedding 236:
#   ID del registro: images/ISIC_0032218_rotated_-10.png
#   Vector: [ 0.01098076 -0.00744153 -0.02058938  0.03189134  0.02763683]... (primeros 5 valores)
#   Imagen: images/ISIC_0032218_rotated_-10.png
#   Otros metadatos: {'type': 'transformed', 'original_image': 'images/ISIC_0032218.png', 'image_type': 'augmented', 'transformations': 'rotated_-10'}
# --------------------------------------------------------------------------------
#
# Embedding 237:
#   ID del registro: images/ISIC_0032415_rotated_-8_contrast_1.05_flipped.png
#   Vector: [ 0.00877429 -0.00850392 -0.01803001  0.03016694  0.03601572]... (primeros 5 valores)
#   Imagen: images/ISIC_0032415_rotated_-8_contrast_1.05_flipped.png
#   Otros metadatos: {'image_type': 'augmented', 'transformations': 'rotated_-8, contrast_1.05, flipped', 'original_image': 'images/ISIC_0032415.png', 'type': 'transformed'}
# --------------------------------------------------------------------------------
#
# Embedding 238:
#   ID del registro: images/ISIC_0032493_rotated_14_brightness_0.95_contrast_0.95.png
#   Vector: [ 0.01972592 -0.00447769 -0.02604528  0.03392862  0.02021309]... (primeros 5 valores)
#   Imagen: images/ISIC_0032493_rotated_14_brightness_0.95_contrast_0.95.png
#   Otros metadatos: {'original_image': 'images/ISIC_0032493.png', 'transformations': 'rotated_14, brightness_0.95, contrast_0.95', 'type': 'transformed', 'image_type': 'augmented'}
# --------------------------------------------------------------------------------
#
# Embedding 239:
#   ID del registro: images/ISIC_0032563_rotated_-8_contrast_0.84.png
#   Vector: [ 0.03094118 -0.0046575  -0.03269023  0.01614989 -0.00711074]... (primeros 5 valores)
#   Imagen: images/ISIC_0032563_rotated_-8_contrast_0.84.png
#   Otros metadatos: {'type': 'transformed', 'original_image': 'images/ISIC_0032563.png', 'transformations': 'rotated_-8, contrast_0.84', 'image_type': 'augmented'}
# --------------------------------------------------------------------------------
#
# Embedding 240:
#   ID del registro: images/ISIC_0032701_rotated_3_flipped.png
#   Vector: [ 0.024602    0.00057421 -0.01359574  0.02375505  0.02299483]... (primeros 5 valores)
#   Imagen: images/ISIC_0032701_rotated_3_flipped.png
#   Otros metadatos: {'transformations': 'rotated_3, flipped', 'type': 'transformed', 'original_image': 'images/ISIC_0032701.png', 'image_type': 'augmented'}
# --------------------------------------------------------------------------------
#
# Embedding 241:
#   ID del registro: images/ISIC_0032727_brightness_1.07_flipped.png
#   Vector: [ 0.01449619 -0.00487235 -0.03079671  0.0230245   0.00420056]... (primeros 5 valores)
#   Imagen: images/ISIC_0032727_brightness_1.07_flipped.png
#   Otros metadatos: {'transformations': 'brightness_1.07, flipped', 'type': 'transformed', 'original_image': 'images/ISIC_0032727.png', 'image_type': 'augmented'}
# --------------------------------------------------------------------------------
#
# Embedding 242:
#   ID del registro: images/ISIC_0032731_brightness_1.06_contrast_1.16.png
#   Vector: [-0.00543496 -0.02026988 -0.02104356  0.01679198  0.01844426]... (primeros 5 valores)
#   Imagen: images/ISIC_0032731_brightness_1.06_contrast_1.16.png
#   Otros metadatos: {'transformations': 'brightness_1.06, contrast_1.16', 'image_type': 'augmented', 'type': 'transformed', 'original_image': 'images/ISIC_0032731.png'}
# --------------------------------------------------------------------------------
#
# Embedding 243:
#   ID del registro: images/ISIC_0032871_rotated_-11_flipped.png
#   Vector: [ 0.02741379 -0.00411098 -0.02868336  0.00546328  0.0166473 ]... (primeros 5 valores)
#   Imagen: images/ISIC_0032871_rotated_-11_flipped.png
#   Otros metadatos: {'image_type': 'augmented', 'original_image': 'images/ISIC_0032871.png', 'transformations': 'rotated_-11, flipped', 'type': 'transformed'}
# --------------------------------------------------------------------------------
#
# Embedding 244:
#   ID del registro: images/ISIC_0033053_brightness_1.08_contrast_1.09.png
#   Vector: [ 0.0127924  -0.01876537 -0.02191363  0.01176466  0.02438521]... (primeros 5 valores)
#   Imagen: images/ISIC_0033053_brightness_1.08_contrast_1.09.png
#   Otros metadatos: {'image_type': 'augmented', 'transformations': 'brightness_1.08, contrast_1.09', 'original_image': 'images/ISIC_0033053.png', 'type': 'transformed'}
# --------------------------------------------------------------------------------
#
# Embedding 245:
#   ID del registro: images/ISIC_0033055_rotated_10_brightness_1.15_flipped.png
#   Vector: [ 0.01359867 -0.01323834 -0.02127117  0.01146805  0.01119021]... (primeros 5 valores)
#   Imagen: images/ISIC_0033055_rotated_10_brightness_1.15_flipped.png
#   Otros metadatos: {'original_image': 'images/ISIC_0033055.png', 'transformations': 'rotated_10, brightness_1.15, flipped', 'type': 'transformed', 'image_type': 'augmented'}
# --------------------------------------------------------------------------------
#
# Embedding 246:
#   ID del registro: images/ISIC_0033103_rotated_-7.png
#   Vector: [ 0.00108222 -0.00373612 -0.01364013  0.0058322   0.03008983]... (primeros 5 valores)
#   Imagen: images/ISIC_0033103_rotated_-7.png
#   Otros metadatos: {'original_image': 'images/ISIC_0033103.png', 'image_type': 'augmented', 'type': 'transformed', 'transformations': 'rotated_-7'}
# --------------------------------------------------------------------------------
#
# Embedding 247:
#   ID del registro: images/ISIC_0033154_rotated_13_flipped.png
#   Vector: [ 0.01306645 -0.01879198 -0.02370193  0.01970185  0.01200713]... (primeros 5 valores)
#   Imagen: images/ISIC_0033154_rotated_13_flipped.png
#   Otros metadatos: {'image_type': 'augmented', 'type': 'transformed', 'transformations': 'rotated_13, flipped', 'original_image': 'images/ISIC_0033154.png'}
# --------------------------------------------------------------------------------
#
# Embedding 248:
#   ID del registro: images/ISIC_0033229_brightness_1.01_flipped.png
#   Vector: [ 0.00862189 -0.00978075 -0.01577169  0.01623087  0.0303793 ]... (primeros 5 valores)
#   Imagen: images/ISIC_0033229_brightness_1.01_flipped.png
#   Otros metadatos: {'image_type': 'augmented', 'original_image': 'images/ISIC_0033229.png', 'transformations': 'brightness_1.01, flipped', 'type': 'transformed'}
# --------------------------------------------------------------------------------
#
# Embedding 249:
#   ID del registro: images/ISIC_0033439_brightness_0.89.png
#   Vector: [ 2.8989447e-02 -4.5732777e-05 -2.0837491e-02  2.2806369e-02
#   3.3361110e-02]... (primeros 5 valores)
#   Imagen: images/ISIC_0033439_brightness_0.89.png
#   Otros metadatos: {'transformations': 'brightness_0.89', 'original_image': 'images/ISIC_0033439.png', 'image_type': 'augmented', 'type': 'transformed'}
# --------------------------------------------------------------------------------
#
# Embedding 250:
#   ID del registro: images/ISIC_0033464_brightness_0.99_contrast_1.12_flipped.png
#   Vector: [-0.00089072 -0.0173342  -0.02344826  0.03048195  0.0232795 ]... (primeros 5 valores)
#   Imagen: images/ISIC_0033464_brightness_0.99_contrast_1.12_flipped.png
#   Otros metadatos: {'image_type': 'augmented', 'original_image': 'images/ISIC_0033464.png', 'type': 'transformed', 'transformations': 'brightness_0.99, contrast_1.12, flipped'}
# --------------------------------------------------------------------------------
#
# Embedding 251:
#   ID del registro: images/ISIC_0033466_brightness_0.95_flipped.png
#   Vector: [ 0.00904134 -0.00865224 -0.01528876  0.01970995  0.02214283]... (primeros 5 valores)
#   Imagen: images/ISIC_0033466_brightness_0.95_flipped.png
#   Otros metadatos: {'image_type': 'augmented', 'type': 'transformed', 'original_image': 'images/ISIC_0033466.png', 'transformations': 'brightness_0.95, flipped'}
# --------------------------------------------------------------------------------
#
# Embedding 252:
#   ID del registro: images/ISIC_0033505_brightness_1.06_contrast_0.94_flipped.png
#   Vector: [ 0.02219354  0.0041886  -0.01838255  0.01932801  0.04327136]... (primeros 5 valores)
#   Imagen: images/ISIC_0033505_brightness_1.06_contrast_0.94_flipped.png
#   Otros metadatos: {'transformations': 'brightness_1.06, contrast_0.94, flipped', 'image_type': 'augmented', 'original_image': 'images/ISIC_0033505.png', 'type': 'transformed'}
# --------------------------------------------------------------------------------
#
# Embedding 253:
#   ID del registro: images/ISIC_0033786_augmented.png
#   Vector: [-0.00275675 -0.00719728 -0.01246944  0.03016599  0.02655018]... (primeros 5 valores)
#   Imagen: images/ISIC_0033786_augmented.png
#   Otros metadatos: {'image_type': 'augmented', 'type': 'transformed', 'original_image': 'images/ISIC_0033786.png', 'transformations': 'none'}
# --------------------------------------------------------------------------------
#
# Embedding 254:
#   ID del registro: images/ISIC_0034016_brightness_1.09_flipped.png
#   Vector: [ 0.02357562 -0.02299239 -0.01778263  0.00147513  0.00281878]... (primeros 5 valores)
#   Imagen: images/ISIC_0034016_brightness_1.09_flipped.png
#   Otros metadatos: {'transformations': 'brightness_1.09, flipped', 'image_type': 'augmented', 'type': 'transformed', 'original_image': 'images/ISIC_0034016.png'}
# --------------------------------------------------------------------------------
#
# Embedding 255:
#   ID del registro: images/ISIC_0034128_rotated_-6_brightness_1.06_contrast_0.93_flipped.png
#   Vector: [ 0.00427454 -0.00230343 -0.03143026  0.02389285  0.02376059]... (primeros 5 valores)
#   Imagen: images/ISIC_0034128_rotated_-6_brightness_1.06_contrast_0.93_flipped.png
#   Otros metadatos: {'type': 'transformed', 'transformations': 'rotated_-6, brightness_1.06, contrast_0.93, flipped', 'image_type': 'augmented', 'original_image': 'images/ISIC_0034128.png'}
# --------------------------------------------------------------------------------
#
# Embedding 256:
#   ID del registro: images/ISIC_0034129_contrast_0.92.png
#   Vector: [ 0.01352043 -0.01510679 -0.02055673  0.01707948 -0.00726165]... (primeros 5 valores)
#   Imagen: images/ISIC_0034129_contrast_0.92.png
#   Otros metadatos: {'type': 'transformed', 'transformations': 'contrast_0.92', 'image_type': 'augmented', 'original_image': 'images/ISIC_0034129.png'}
# --------------------------------------------------------------------------------
#
# Embedding 257:
#   ID del registro: images/ISIC_0034144_rotated_-14_brightness_0.84_contrast_0.81.png
#   Vector: [ 0.02255539 -0.00512712 -0.02764391  0.03434591 -0.00240927]... (primeros 5 valores)
#   Imagen: images/ISIC_0034144_rotated_-14_brightness_0.84_contrast_0.81.png
#   Otros metadatos: {'type': 'transformed', 'transformations': 'rotated_-14, brightness_0.84, contrast_0.81', 'image_type': 'augmented', 'original_image': 'images/ISIC_0034144.png'}
# --------------------------------------------------------------------------------
#
# Embedding 258:
#   ID del registro: images/ISIC_0034196_brightness_0.97_contrast_1.05_flipped.png
#   Vector: [-0.00603145 -0.02359565 -0.01855343  0.01444226  0.00918422]... (primeros 5 valores)
#   Imagen: images/ISIC_0034196_brightness_0.97_contrast_1.05_flipped.png
#   Otros metadatos: {'type': 'transformed', 'transformations': 'brightness_0.97, contrast_1.05, flipped', 'original_image': 'images/ISIC_0034196.png', 'image_type': 'augmented'}
# --------------------------------------------------------------------------------
#
# Embedding 259:
#   ID del registro: images/ISIC_0034222_contrast_1.15_flipped.png
#   Vector: [ 0.01433372 -0.02409759 -0.0287529   0.01377942 -0.00288303]... (primeros 5 valores)
#   Imagen: images/ISIC_0034222_contrast_1.15_flipped.png
#   Otros metadatos: {'original_image': 'images/ISIC_0034222.png', 'transformations': 'contrast_1.15, flipped', 'type': 'transformed', 'image_type': 'augmented'}
# --------------------------------------------------------------------------------
#
# Resumen:
#   Total de embeddings únicos: 259
#   Total de imágenes (originales + transformadas): 359

# %%
data2 = collection_image.get(include=["metadatas", "documents", "embeddings"])
# For to seee for each embedding all the information

for idx, (embedding, img_id, metadata) in enumerate(zip(data2["embeddings"], data2["ids"], data2["metadatas"])):
    print(f"\nEmbedding {idx + 1}:")
    print(f"  ID del registro: {img_id}")
    print(f"  Vector: {embedding[:5]}... (primeros 5 valores)")
    
    if metadata:
        print(f"  Otros metadatos: {metadata}")
    print("-" * 80)

print(f"\nResumen:")
print(f"  Total de embeddings únicos: {len(data2['ids'])}")
print(f"  Total de imágenes (originales + transformadas): {total_images_count}")
# Out:
# Embedding 1:
#   ID del registro: images/ISIC_0024388.png
#   Vector: [ 0.00830536  0.01662186 -0.01564987  0.04551699  0.0083858 ]... (primeros 5 valores)
#   Otros metadatos: {'associated_images': 'images/ISIC_0024388.png,images/ISIC_0024388_contrast_1.19_flipped.png', 'transformations_info': 'images/ISIC_0024388_contrast_1.19_flipped.png:contrast_1.19, flipped', 'image_type': 'original', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 2:
#   ID del registro: images/ISIC_0024508.png
#   Vector: [-0.01091168 -0.02055728 -0.04908438  0.04230993  0.01473207]... (primeros 5 valores)
#   Otros metadatos: {'image_type': 'original', 'associated_images': 'images/ISIC_0024508.png,images/ISIC_0024508_rotated_-13_brightness_1.03_flipped.png', 'type': 'original', 'transformations_info': 'images/ISIC_0024508_rotated_-13_brightness_1.03_flipped.png:rotated_-13, brightness_1.03, flipped'}
# --------------------------------------------------------------------------------
#
# Embedding 3:
#   ID del registro: images/ISIC_0024853.png
#   Vector: [ 0.00449441  0.00574136 -0.01411529  0.01850141  0.0137807 ]... (primeros 5 valores)
#   Otros metadatos: {'image_type': 'original', 'associated_images': 'images/ISIC_0024853.png,images/ISIC_0024853_brightness_0.82_contrast_1.15_flipped.png', 'type': 'original', 'transformations_info': 'images/ISIC_0024853_brightness_0.82_contrast_1.15_flipped.png:brightness_0.82, contrast_1.15, flipped'}
# --------------------------------------------------------------------------------
#
# Embedding 4:
#   ID del registro: images/ISIC_0025118.png
#   Vector: [ 0.01125942 -0.00936773 -0.02758692  0.0212735   0.01231156]... (primeros 5 valores)
#   Otros metadatos: {'transformations_info': 'images/ISIC_0025118_brightness_1.19.png:brightness_1.19', 'image_type': 'original', 'type': 'original', 'associated_images': 'images/ISIC_0025118.png,images/ISIC_0025118_brightness_1.19.png'}
# --------------------------------------------------------------------------------
#
# Embedding 5:
#   ID del registro: images/ISIC_0025200.png
#   Vector: [ 0.00344155 -0.030877   -0.01998417  0.02646288  0.01467685]... (primeros 5 valores)
#   Otros metadatos: {'type': 'original', 'image_type': 'original', 'associated_images': 'images/ISIC_0025200.png,images/ISIC_0025200_rotated_-5_contrast_0.94.png', 'transformations_info': 'images/ISIC_0025200_rotated_-5_contrast_0.94.png:rotated_-5, contrast_0.94'}
# --------------------------------------------------------------------------------
#
# Embedding 6:
#   ID del registro: images/ISIC_0025202.png
#   Vector: [ 0.02445663  0.00724421 -0.02728193  0.0364267   0.03225328]... (primeros 5 valores)
#   Otros metadatos: {'image_type': 'original', 'transformations_info': 'images/ISIC_0025202_rotated_2_contrast_0.96_flipped.png:rotated_2, contrast_0.96, flipped', 'type': 'original', 'associated_images': 'images/ISIC_0025202.png,images/ISIC_0025202_rotated_2_contrast_0.96_flipped.png'}
# --------------------------------------------------------------------------------
#
# Embedding 7:
#   ID del registro: images/ISIC_0025298.png
#   Vector: [ 0.01374584 -0.01879584 -0.03148149  0.0285682   0.00361107]... (primeros 5 valores)
#   Otros metadatos: {'type': 'original', 'image_type': 'original', 'associated_images': 'images/ISIC_0025298.png,images/ISIC_0025298_rotated_3_contrast_1.11.png', 'transformations_info': 'images/ISIC_0025298_rotated_3_contrast_1.11.png:rotated_3, contrast_1.11'}
# --------------------------------------------------------------------------------
#
# Embedding 8:
#   ID del registro: images/ISIC_0025343.png
#   Vector: [ 0.01280284 -0.02143798 -0.0403423   0.03259989  0.00867019]... (primeros 5 valores)
#   Otros metadatos: {'associated_images': 'images/ISIC_0025343.png,images/ISIC_0025343_flipped.png', 'type': 'original', 'transformations_info': 'images/ISIC_0025343_flipped.png:flipped', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 9:
#   ID del registro: images/ISIC_0025430.png
#   Vector: [ 0.00133812 -0.01886196 -0.04037132  0.03862811  0.02257077]... (primeros 5 valores)
#   Otros metadatos: {'transformations_info': 'images/ISIC_0025430_rotated_4_brightness_1.12_contrast_0.96.png:rotated_4, brightness_1.12, contrast_0.96', 'image_type': 'original', 'type': 'original', 'associated_images': 'images/ISIC_0025430.png,images/ISIC_0025430_rotated_4_brightness_1.12_contrast_0.96.png'}
# --------------------------------------------------------------------------------
#
# Embedding 10:
#   ID del registro: images/ISIC_0025806.png
#   Vector: [-0.0154553  -0.01123594 -0.03954926  0.04713185  0.01786992]... (primeros 5 valores)
#   Otros metadatos: {'associated_images': 'images/ISIC_0025806.png,images/ISIC_0025806_rotated_-4.png', 'type': 'original', 'transformations_info': 'images/ISIC_0025806_rotated_-4.png:rotated_-4', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 11:
#   ID del registro: images/ISIC_0025874.png
#   Vector: [ 0.0127736   0.00149205 -0.01069783  0.0141592   0.01889801]... (primeros 5 valores)
#   Otros metadatos: {'associated_images': 'images/ISIC_0025874.png,images/ISIC_0025874_brightness_1.15_contrast_0.99.png', 'image_type': 'original', 'type': 'original', 'transformations_info': 'images/ISIC_0025874_brightness_1.15_contrast_0.99.png:brightness_1.15, contrast_0.99'}
# --------------------------------------------------------------------------------
#
# Embedding 12:
#   ID del registro: images/ISIC_0025886.png
#   Vector: [ 0.01317594 -0.01082373 -0.05005679  0.03517215  0.02201676]... (primeros 5 valores)
#   Otros metadatos: {'type': 'original', 'transformations_info': 'images/ISIC_0025886_rotated_-2_brightness_0.99.png:rotated_-2, brightness_0.99', 'image_type': 'original', 'associated_images': 'images/ISIC_0025886.png,images/ISIC_0025886_rotated_-2_brightness_0.99.png'}
# --------------------------------------------------------------------------------
#
# Embedding 13:
#   ID del registro: images/ISIC_0025899.png
#   Vector: [ 0.01393954 -0.00300591 -0.010154    0.00699406  0.01209712]... (primeros 5 valores)
#   Otros metadatos: {'type': 'original', 'transformations_info': 'images/ISIC_0025899_contrast_1.15_flipped.png:contrast_1.15, flipped', 'associated_images': 'images/ISIC_0025899.png,images/ISIC_0025899_contrast_1.15_flipped.png', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 14:
#   ID del registro: images/ISIC_0025960.png
#   Vector: [ 0.01572194 -0.00879369 -0.00869887  0.00949537  0.00369583]... (primeros 5 valores)
#   Otros metadatos: {'image_type': 'original', 'type': 'original', 'associated_images': 'images/ISIC_0025960.png,images/ISIC_0025960_augmented.png', 'transformations_info': 'images/ISIC_0025960_augmented.png:none'}
# --------------------------------------------------------------------------------
#
# Embedding 15:
#   ID del registro: images/ISIC_0026077.png
#   Vector: [ 0.01854017 -0.01351146 -0.05295406  0.04876968 -0.01487969]... (primeros 5 valores)
#   Otros metadatos: {'transformations_info': 'images/ISIC_0026077_brightness_0.98_flipped.png:brightness_0.98, flipped', 'image_type': 'original', 'type': 'original', 'associated_images': 'images/ISIC_0026077.png,images/ISIC_0026077_brightness_0.98_flipped.png'}
# --------------------------------------------------------------------------------
#
# Embedding 16:
#   ID del registro: images/ISIC_0026128.png
#   Vector: [ 1.3351330e-03 -6.4717340e-05 -3.8560145e-02  2.4081085e-02
#   2.8792318e-02]... (primeros 5 valores)
#   Otros metadatos: {'image_type': 'original', 'transformations_info': 'images/ISIC_0026128_brightness_0.81_contrast_1.07_flipped.png:brightness_0.81, contrast_1.07, flipped', 'type': 'original', 'associated_images': 'images/ISIC_0026128.png,images/ISIC_0026128_brightness_0.81_contrast_1.07_flipped.png'}
# --------------------------------------------------------------------------------
#
# Embedding 17:
#   ID del registro: images/ISIC_0026152.png
#   Vector: [ 0.01217128 -0.00189536 -0.03640664  0.03415362  0.02888421]... (primeros 5 valores)
#   Otros metadatos: {'type': 'original', 'associated_images': 'images/ISIC_0026152.png,images/ISIC_0026152_rotated_1_flipped.png', 'image_type': 'original', 'transformations_info': 'images/ISIC_0026152_rotated_1_flipped.png:rotated_1, flipped'}
# --------------------------------------------------------------------------------
#
# Embedding 18:
#   ID del registro: images/ISIC_0026283.png
#   Vector: [ 0.02081151 -0.00115781 -0.0211343   0.03164659  0.01210109]... (primeros 5 valores)
#   Otros metadatos: {'transformations_info': 'images/ISIC_0026283_rotated_3_contrast_0.82.png:rotated_3, contrast_0.82', 'image_type': 'original', 'associated_images': 'images/ISIC_0026283.png,images/ISIC_0026283_rotated_3_contrast_0.82.png', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 19:
#   ID del registro: images/ISIC_0026289.png
#   Vector: [ 0.0169967  -0.00619648 -0.02775804  0.03161497  0.02273474]... (primeros 5 valores)
#   Otros metadatos: {'associated_images': 'images/ISIC_0026289.png,images/ISIC_0026289_contrast_0.93.png', 'type': 'original', 'image_type': 'original', 'transformations_info': 'images/ISIC_0026289_contrast_0.93.png:contrast_0.93'}
# --------------------------------------------------------------------------------
#
# Embedding 20:
#   ID del registro: images/ISIC_0026507.png
#   Vector: [ 0.00308528 -0.0213203  -0.03801672  0.00335722  0.02383137]... (primeros 5 valores)
#   Otros metadatos: {'transformations_info': 'images/ISIC_0026507_rotated_12_brightness_1.08_flipped.png:rotated_12, brightness_1.08, flipped', 'type': 'original', 'associated_images': 'images/ISIC_0026507.png,images/ISIC_0026507_rotated_12_brightness_1.08_flipped.png', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 21:
#   ID del registro: images/ISIC_0026653.png
#   Vector: [ 0.00549644  0.00012924 -0.00913825  0.01207577  0.00627354]... (primeros 5 valores)
#   Otros metadatos: {'image_type': 'original', 'associated_images': 'images/ISIC_0026653.png,images/ISIC_0026653_brightness_0.95.png', 'type': 'original', 'transformations_info': 'images/ISIC_0026653_brightness_0.95.png:brightness_0.95'}
# --------------------------------------------------------------------------------
#
# Embedding 22:
#   ID del registro: images/ISIC_0026710.png
#   Vector: [ 0.01763856 -0.00487728 -0.03017028  0.02215402  0.03055992]... (primeros 5 valores)
#   Otros metadatos: {'associated_images': 'images/ISIC_0026710.png,images/ISIC_0026710_augmented.png', 'type': 'original', 'transformations_info': 'images/ISIC_0026710_augmented.png:none', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 23:
#   ID del registro: images/ISIC_0026803.png
#   Vector: [ 0.02363533  0.00771739 -0.01284052  0.02143278  0.02362205]... (primeros 5 valores)
#   Otros metadatos: {'transformations_info': 'images/ISIC_0026803_brightness_1.01_contrast_0.92_flipped.png:brightness_1.01, contrast_0.92, flipped', 'image_type': 'original', 'associated_images': 'images/ISIC_0026803.png,images/ISIC_0026803_brightness_1.01_contrast_0.92_flipped.png', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 24:
#   ID del registro: images/ISIC_0026911.png
#   Vector: [ 0.01677191 -0.00050146 -0.00777636  0.02543087  0.03239663]... (primeros 5 valores)
#   Otros metadatos: {'type': 'original', 'associated_images': 'images/ISIC_0026911.png,images/ISIC_0026911_rotated_-1_flipped.png', 'transformations_info': 'images/ISIC_0026911_rotated_-1_flipped.png:rotated_-1, flipped', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 25:
#   ID del registro: images/ISIC_0027058.png
#   Vector: [ 0.00515188  0.00259425 -0.01882192  0.03826836  0.00833906]... (primeros 5 valores)
#   Otros metadatos: {'transformations_info': 'images/ISIC_0027058_flipped.png:flipped', 'associated_images': 'images/ISIC_0027058.png,images/ISIC_0027058_flipped.png', 'type': 'original', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 26:
#   ID del registro: images/ISIC_0027077.png
#   Vector: [ 0.02390236 -0.00101899 -0.01779498  0.00880341  0.02474648]... (primeros 5 valores)
#   Otros metadatos: {'image_type': 'original', 'type': 'original', 'associated_images': 'images/ISIC_0027077.png,images/ISIC_0027077_rotated_0_contrast_1.09_flipped.png', 'transformations_info': 'images/ISIC_0027077_rotated_0_contrast_1.09_flipped.png:rotated_0, contrast_1.09, flipped'}
# --------------------------------------------------------------------------------
#
# Embedding 27:
#   ID del registro: images/ISIC_0027209.png
#   Vector: [ 0.01588157 -0.00628285 -0.02420168  0.00308543  0.02197479]... (primeros 5 valores)
#   Otros metadatos: {'associated_images': 'images/ISIC_0027209.png,images/ISIC_0027209_rotated_4_flipped.png', 'image_type': 'original', 'transformations_info': 'images/ISIC_0027209_rotated_4_flipped.png:rotated_4, flipped', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 28:
#   ID del registro: images/ISIC_0027219.png
#   Vector: [ 0.04260688  0.00079807 -0.02911308  0.02631747  0.012279  ]... (primeros 5 valores)
#   Otros metadatos: {'type': 'original', 'image_type': 'original', 'associated_images': 'images/ISIC_0027219.png,images/ISIC_0027219_rotated_11.png', 'transformations_info': 'images/ISIC_0027219_rotated_11.png:rotated_11'}
# --------------------------------------------------------------------------------
#
# Embedding 29:
#   ID del registro: images/ISIC_0027249.png
#   Vector: [ 0.0182446  -0.0015127  -0.00114403  0.01905669  0.0287117 ]... (primeros 5 valores)
#   Otros metadatos: {'associated_images': 'images/ISIC_0027249.png,images/ISIC_0027249_rotated_-12_contrast_1.10.png', 'image_type': 'original', 'type': 'original', 'transformations_info': 'images/ISIC_0027249_rotated_-12_contrast_1.10.png:rotated_-12, contrast_1.10'}
# --------------------------------------------------------------------------------
#
# Embedding 30:
#   ID del registro: images/ISIC_0027307.png
#   Vector: [ 0.01699191  0.00592696 -0.02818497  0.01493816  0.02641014]... (primeros 5 valores)
#   Otros metadatos: {'associated_images': 'images/ISIC_0027307.png,images/ISIC_0027307_rotated_5_brightness_0.81.png', 'transformations_info': 'images/ISIC_0027307_rotated_5_brightness_0.81.png:rotated_5, brightness_0.81', 'image_type': 'original', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 31:
#   ID del registro: images/ISIC_0027620.png
#   Vector: [ 0.0186013  -0.00670073 -0.00948957  0.00939863  0.02056485]... (primeros 5 valores)
#   Otros metadatos: {'transformations_info': 'images/ISIC_0027620_rotated_9.png:rotated_9', 'associated_images': 'images/ISIC_0027620.png,images/ISIC_0027620_rotated_9.png', 'image_type': 'original', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 32:
#   ID del registro: images/ISIC_0027710.png
#   Vector: [ 0.03252639 -0.01369929 -0.02540692  0.01638038  0.03534392]... (primeros 5 valores)
#   Otros metadatos: {'transformations_info': 'images/ISIC_0027710_rotated_4_brightness_0.83_contrast_1.10_flipped.png:rotated_4, brightness_0.83, contrast_1.10, flipped', 'image_type': 'original', 'associated_images': 'images/ISIC_0027710.png,images/ISIC_0027710_rotated_4_brightness_0.83_contrast_1.10_flipped.png', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 33:
#   ID del registro: images/ISIC_0027841.png
#   Vector: [ 0.01318089  0.00972903 -0.04053685  0.04536879  0.01465679]... (primeros 5 valores)
#   Otros metadatos: {'transformations_info': 'images/ISIC_0027841_rotated_13_flipped.png:rotated_13, flipped', 'image_type': 'original', 'type': 'original', 'associated_images': 'images/ISIC_0027841.png,images/ISIC_0027841_rotated_13_flipped.png'}
# --------------------------------------------------------------------------------
#
# Embedding 34:
#   ID del registro: images/ISIC_0027999.png
#   Vector: [ 0.02496729 -0.0065368  -0.02490858  0.008245    0.01651797]... (primeros 5 valores)
#   Otros metadatos: {'type': 'original', 'transformations_info': 'images/ISIC_0027999_augmented.png:none', 'associated_images': 'images/ISIC_0027999.png,images/ISIC_0027999_augmented.png', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 35:
#   ID del registro: images/ISIC_0028025.png
#   Vector: [ 0.00694997 -0.01404682 -0.02731946  0.03250327  0.01721273]... (primeros 5 valores)
#   Otros metadatos: {'type': 'original', 'image_type': 'original', 'associated_images': 'images/ISIC_0028025.png,images/ISIC_0028025_brightness_0.86_contrast_1.03_flipped.png', 'transformations_info': 'images/ISIC_0028025_brightness_0.86_contrast_1.03_flipped.png:brightness_0.86, contrast_1.03, flipped'}
# --------------------------------------------------------------------------------
#
# Embedding 36:
#   ID del registro: images/ISIC_0028103.png
#   Vector: [ 0.01175773  0.01532797 -0.01899275  0.01669494 -0.00077613]... (primeros 5 valores)
#   Otros metadatos: {'type': 'original', 'image_type': 'original', 'transformations_info': 'images/ISIC_0028103_rotated_4_brightness_1.08_flipped.png:rotated_4, brightness_1.08, flipped', 'associated_images': 'images/ISIC_0028103.png,images/ISIC_0028103_rotated_4_brightness_1.08_flipped.png'}
# --------------------------------------------------------------------------------
#
# Embedding 37:
#   ID del registro: images/ISIC_0028175.png
#   Vector: [ 0.02134456 -0.01377021 -0.032189    0.0483725   0.0167377 ]... (primeros 5 valores)
#   Otros metadatos: {'image_type': 'original', 'type': 'original', 'associated_images': 'images/ISIC_0028175.png,images/ISIC_0028175_contrast_0.85.png', 'transformations_info': 'images/ISIC_0028175_contrast_0.85.png:contrast_0.85'}
# --------------------------------------------------------------------------------
#
# Embedding 38:
#   ID del registro: images/ISIC_0028280.png
#   Vector: [ 0.03802249 -0.00509653 -0.01587542  0.03295568  0.01249744]... (primeros 5 valores)
#   Otros metadatos: {'image_type': 'original', 'associated_images': 'images/ISIC_0028280.png,images/ISIC_0028280_rotated_7_brightness_0.96_contrast_0.92.png', 'type': 'original', 'transformations_info': 'images/ISIC_0028280_rotated_7_brightness_0.96_contrast_0.92.png:rotated_7, brightness_0.96, contrast_0.92'}
# --------------------------------------------------------------------------------
#
# Embedding 39:
#   ID del registro: images/ISIC_0028381.png
#   Vector: [ 0.02123318 -0.01242245 -0.02104927  0.00624634  0.02476739]... (primeros 5 valores)
#   Otros metadatos: {'image_type': 'original', 'transformations_info': 'images/ISIC_0028381_rotated_1_brightness_0.83_flipped.png:rotated_1, brightness_0.83, flipped', 'associated_images': 'images/ISIC_0028381.png,images/ISIC_0028381_rotated_1_brightness_0.83_flipped.png', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 40:
#   ID del registro: images/ISIC_0028416.png
#   Vector: [ 0.02456519 -0.01241321 -0.01480728  0.02247219  0.02908975]... (primeros 5 valores)
#   Otros metadatos: {'image_type': 'original', 'transformations_info': 'images/ISIC_0028416_rotated_11_brightness_0.93_contrast_1.12_flipped.png:rotated_11, brightness_0.93, contrast_1.12, flipped', 'type': 'original', 'associated_images': 'images/ISIC_0028416.png,images/ISIC_0028416_rotated_11_brightness_0.93_contrast_1.12_flipped.png'}
# --------------------------------------------------------------------------------
#
# Embedding 41:
#   ID del registro: images/ISIC_0028726.png
#   Vector: [ 0.00189383 -0.01283241 -0.0054169   0.03762672  0.02429997]... (primeros 5 valores)
#   Otros metadatos: {'transformations_info': 'images/ISIC_0028726_rotated_-11_brightness_0.95_flipped.png:rotated_-11, brightness_0.95, flipped', 'image_type': 'original', 'associated_images': 'images/ISIC_0028726.png,images/ISIC_0028726_rotated_-11_brightness_0.95_flipped.png', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 42:
#   ID del registro: images/ISIC_0028948.png
#   Vector: [ 0.02947219 -0.00918802 -0.01968661  0.02618798  0.02938912]... (primeros 5 valores)
#   Otros metadatos: {'transformations_info': 'images/ISIC_0028948_contrast_0.94_flipped.png:contrast_0.94, flipped', 'associated_images': 'images/ISIC_0028948.png,images/ISIC_0028948_contrast_0.94_flipped.png', 'image_type': 'original', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 43:
#   ID del registro: images/ISIC_0029024.png
#   Vector: [ 0.01495899 -0.00964392 -0.01459762  0.04277553  0.0126628 ]... (primeros 5 valores)
#   Otros metadatos: {'image_type': 'original', 'associated_images': 'images/ISIC_0029024.png,images/ISIC_0029024_rotated_-5_contrast_1.17.png', 'type': 'original', 'transformations_info': 'images/ISIC_0029024_rotated_-5_contrast_1.17.png:rotated_-5, contrast_1.17'}
# --------------------------------------------------------------------------------
#
# Embedding 44:
#   ID del registro: images/ISIC_0029220.png
#   Vector: [ 0.00753813 -0.00493855 -0.00908423  0.02196785  0.02777001]... (primeros 5 valores)
#   Otros metadatos: {'type': 'original', 'associated_images': 'images/ISIC_0029220.png,images/ISIC_0029220_rotated_5_flipped.png', 'transformations_info': 'images/ISIC_0029220_rotated_5_flipped.png:rotated_5, flipped', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 45:
#   ID del registro: images/ISIC_0029263.png
#   Vector: [ 8.2252810e-03  3.5357232e-05 -4.8124865e-03 -7.5221527e-03
#  -9.1204260e-03]... (primeros 5 valores)
#   Otros metadatos: {'transformations_info': 'images/ISIC_0029263_rotated_-12_contrast_1.17_flipped.png:rotated_-12, contrast_1.17, flipped', 'image_type': 'original', 'associated_images': 'images/ISIC_0029263.png,images/ISIC_0029263_rotated_-12_contrast_1.17_flipped.png', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 46:
#   ID del registro: images/ISIC_0029475.png
#   Vector: [ 2.1412686e-02  2.1090347e-05 -2.1682028e-02  3.3635604e-03
#   4.1777864e-03]... (primeros 5 valores)
#   Otros metadatos: {'type': 'original', 'transformations_info': 'images/ISIC_0029475_rotated_15_brightness_1.01_contrast_1.03.png:rotated_15, brightness_1.01, contrast_1.03', 'image_type': 'original', 'associated_images': 'images/ISIC_0029475.png,images/ISIC_0029475_rotated_15_brightness_1.01_contrast_1.03.png'}
# --------------------------------------------------------------------------------
#
# Embedding 47:
#   ID del registro: images/ISIC_0029577.png
#   Vector: [ 0.01000569 -0.00626472 -0.01028662  0.01742344  0.02143859]... (primeros 5 valores)
#   Otros metadatos: {'image_type': 'original', 'associated_images': 'images/ISIC_0029577.png,images/ISIC_0029577_brightness_1.00_flipped.png', 'type': 'original', 'transformations_info': 'images/ISIC_0029577_brightness_1.00_flipped.png:brightness_1.00, flipped'}
# --------------------------------------------------------------------------------
#
# Embedding 48:
#   ID del registro: images/ISIC_0029623.png
#   Vector: [-0.02008211  0.00121557 -0.0462766   0.0278461   0.01989276]... (primeros 5 valores)
#   Otros metadatos: {'type': 'original', 'transformations_info': 'images/ISIC_0029623_brightness_1.09_contrast_1.00.png:brightness_1.09, contrast_1.00', 'image_type': 'original', 'associated_images': 'images/ISIC_0029623.png,images/ISIC_0029623_brightness_1.09_contrast_1.00.png'}
# --------------------------------------------------------------------------------
#
# Embedding 49:
#   ID del registro: images/ISIC_0029649.png
#   Vector: [ 0.02471597  0.00227088 -0.00860027  0.02903089  0.01550372]... (primeros 5 valores)
#   Otros metadatos: {'image_type': 'original', 'associated_images': 'images/ISIC_0029649.png,images/ISIC_0029649_rotated_0_brightness_0.96_contrast_1.09.png', 'transformations_info': 'images/ISIC_0029649_rotated_0_brightness_0.96_contrast_1.09.png:rotated_0, brightness_0.96, contrast_1.09', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 50:
#   ID del registro: images/ISIC_0029694.png
#   Vector: [-0.01433282 -0.01553226 -0.02237825  0.03944887  0.00743286]... (primeros 5 valores)
#   Otros metadatos: {'image_type': 'original', 'associated_images': 'images/ISIC_0029694.png,images/ISIC_0029694_rotated_9_flipped.png', 'type': 'original', 'transformations_info': 'images/ISIC_0029694_rotated_9_flipped.png:rotated_9, flipped'}
# --------------------------------------------------------------------------------
#
# Embedding 51:
#   ID del registro: images/ISIC_0029834.png
#   Vector: [ 0.01694005 -0.01102383 -0.01961614  0.04080529  0.02083127]... (primeros 5 valores)
#   Otros metadatos: {'type': 'original', 'associated_images': 'images/ISIC_0029834.png,images/ISIC_0029834_rotated_-14.png', 'transformations_info': 'images/ISIC_0029834_rotated_-14.png:rotated_-14', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 52:
#   ID del registro: images/ISIC_0029851.png
#   Vector: [-0.00196411 -0.00774993 -0.00320553 -0.00198832 -0.01349081]... (primeros 5 valores)
#   Otros metadatos: {'associated_images': 'images/ISIC_0029851.png,images/ISIC_0029851_rotated_-9_brightness_1.15_contrast_0.82_flipped.png', 'transformations_info': 'images/ISIC_0029851_rotated_-9_brightness_1.15_contrast_0.82_flipped.png:rotated_-9, brightness_1.15, contrast_0.82, flipped', 'type': 'original', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 53:
#   ID del registro: images/ISIC_0029876.png
#   Vector: [ 0.02997167 -0.00345055 -0.01921082  0.02212277  0.02241677]... (primeros 5 valores)
#   Otros metadatos: {'image_type': 'original', 'transformations_info': 'images/ISIC_0029876_rotated_-15_brightness_0.95_flipped.png:rotated_-15, brightness_0.95, flipped', 'type': 'original', 'associated_images': 'images/ISIC_0029876.png,images/ISIC_0029876_rotated_-15_brightness_0.95_flipped.png'}
# --------------------------------------------------------------------------------
#
# Embedding 54:
#   ID del registro: images/ISIC_0029896.png
#   Vector: [ 0.02036635  0.00269524 -0.00724164  0.02480619  0.0149514 ]... (primeros 5 valores)
#   Otros metadatos: {'associated_images': 'images/ISIC_0029896.png,images/ISIC_0029896_brightness_0.91_flipped.png', 'image_type': 'original', 'type': 'original', 'transformations_info': 'images/ISIC_0029896_brightness_0.91_flipped.png:brightness_0.91, flipped'}
# --------------------------------------------------------------------------------
#
# Embedding 55:
#   ID del registro: images/ISIC_0029929.png
#   Vector: [-0.01848452 -0.00058775  0.00345549  0.01731116 -0.00907827]... (primeros 5 valores)
#   Otros metadatos: {'transformations_info': 'images/ISIC_0029929_brightness_1.02_contrast_0.90_flipped.png:brightness_1.02, contrast_0.90, flipped', 'type': 'original', 'image_type': 'original', 'associated_images': 'images/ISIC_0029929.png,images/ISIC_0029929_brightness_1.02_contrast_0.90_flipped.png'}
# --------------------------------------------------------------------------------
#
# Embedding 56:
#   ID del registro: images/ISIC_0030055.png
#   Vector: [-0.02568738 -0.01163389 -0.04184473  0.03440484  0.02538315]... (primeros 5 valores)
#   Otros metadatos: {'image_type': 'original', 'transformations_info': 'images/ISIC_0030055_rotated_3_contrast_0.88_flipped.png:rotated_3, contrast_0.88, flipped', 'associated_images': 'images/ISIC_0030055.png,images/ISIC_0030055_rotated_3_contrast_0.88_flipped.png', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 57:
#   ID del registro: images/ISIC_0030197.png
#   Vector: [-0.00354442 -0.00551159 -0.02661058  0.03213561  0.00099803]... (primeros 5 valores)
#   Otros metadatos: {'type': 'original', 'associated_images': 'images/ISIC_0030197.png,images/ISIC_0030197_augmented.png', 'image_type': 'original', 'transformations_info': 'images/ISIC_0030197_augmented.png:none'}
# --------------------------------------------------------------------------------
#
# Embedding 58:
#   ID del registro: images/ISIC_0030269.png
#   Vector: [ 0.01595645 -0.00933474 -0.01440552  0.01815461  0.01576128]... (primeros 5 valores)
#   Otros metadatos: {'transformations_info': 'images/ISIC_0030269_contrast_0.92_flipped.png:contrast_0.92, flipped', 'type': 'original', 'image_type': 'original', 'associated_images': 'images/ISIC_0030269.png,images/ISIC_0030269_contrast_0.92_flipped.png'}
# --------------------------------------------------------------------------------
#
# Embedding 59:
#   ID del registro: images/ISIC_0030297.png
#   Vector: [-0.00217325  0.00569339 -0.01507764  0.02366368  0.01927417]... (primeros 5 valores)
#   Otros metadatos: {'transformations_info': 'images/ISIC_0030297_rotated_-12_contrast_0.98.png:rotated_-12, contrast_0.98', 'associated_images': 'images/ISIC_0030297.png,images/ISIC_0030297_rotated_-12_contrast_0.98.png', 'image_type': 'original', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 60:
#   ID del registro: images/ISIC_0030397.png
#   Vector: [ 0.0351996  -0.00190885 -0.01139083  0.03411646  0.02433438]... (primeros 5 valores)
#   Otros metadatos: {'image_type': 'original', 'associated_images': 'images/ISIC_0030397.png,images/ISIC_0030397_contrast_1.01_flipped.png', 'transformations_info': 'images/ISIC_0030397_contrast_1.01_flipped.png:contrast_1.01, flipped', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 61:
#   ID del registro: images/ISIC_0030413.png
#   Vector: [ 0.00478846 -0.01809259 -0.02284605  0.03024457  0.01995391]... (primeros 5 valores)
#   Otros metadatos: {'image_type': 'original', 'associated_images': 'images/ISIC_0030413.png,images/ISIC_0030413_rotated_-1_brightness_1.10_contrast_1.19.png', 'transformations_info': 'images/ISIC_0030413_rotated_-1_brightness_1.10_contrast_1.19.png:rotated_-1, brightness_1.10, contrast_1.19', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 62:
#   ID del registro: images/ISIC_0030421.png
#   Vector: [ 0.01250534  0.0023085  -0.00865806  0.02127539  0.02768262]... (primeros 5 valores)
#   Otros metadatos: {'transformations_info': 'images/ISIC_0030421_rotated_3_brightness_1.02_contrast_0.96.png:rotated_3, brightness_1.02, contrast_0.96', 'type': 'original', 'associated_images': 'images/ISIC_0030421.png,images/ISIC_0030421_rotated_3_brightness_1.02_contrast_0.96.png', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 63:
#   ID del registro: images/ISIC_0030492.png
#   Vector: [ 0.02519039 -0.01236645 -0.01297046  0.01038481  0.00146877]... (primeros 5 valores)
#   Otros metadatos: {'transformations_info': 'images/ISIC_0030492_brightness_0.97_contrast_0.96_flipped.png:brightness_0.97, contrast_0.96, flipped', 'associated_images': 'images/ISIC_0030492.png,images/ISIC_0030492_brightness_0.97_contrast_0.96_flipped.png', 'type': 'original', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 64:
#   ID del registro: images/ISIC_0030541.png
#   Vector: [ 0.02033612 -0.01682206 -0.03807076  0.01606102  0.01126429]... (primeros 5 valores)
#   Otros metadatos: {'associated_images': 'images/ISIC_0030541.png,images/ISIC_0030541_rotated_-6_brightness_1.18_flipped.png', 'type': 'original', 'image_type': 'original', 'transformations_info': 'images/ISIC_0030541_rotated_-6_brightness_1.18_flipped.png:rotated_-6, brightness_1.18, flipped'}
# --------------------------------------------------------------------------------
#
# Embedding 65:
#   ID del registro: images/ISIC_0031256.png
#   Vector: [ 0.0123255  -0.01412114 -0.02105487  0.01568349  0.0279504 ]... (primeros 5 valores)
#   Otros metadatos: {'associated_images': 'images/ISIC_0031256.png,images/ISIC_0031256_brightness_0.99_contrast_1.06.png', 'type': 'original', 'transformations_info': 'images/ISIC_0031256_brightness_0.99_contrast_1.06.png:brightness_0.99, contrast_1.06', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 66:
#   ID del registro: images/ISIC_0031351.png
#   Vector: [ 0.01103398 -0.01615845 -0.0235995   0.0119728  -0.00214551]... (primeros 5 valores)
#   Otros metadatos: {'transformations_info': 'images/ISIC_0031351_flipped.png:flipped', 'type': 'original', 'associated_images': 'images/ISIC_0031351.png,images/ISIC_0031351_flipped.png', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 67:
#   ID del registro: images/ISIC_0031380.png
#   Vector: [ 0.00897837 -0.00755948 -0.01936218  0.02052956  0.0110663 ]... (primeros 5 valores)
#   Otros metadatos: {'associated_images': 'images/ISIC_0031380.png,images/ISIC_0031380_rotated_14_brightness_0.97_contrast_1.06_flipped.png', 'transformations_info': 'images/ISIC_0031380_rotated_14_brightness_0.97_contrast_1.06_flipped.png:rotated_14, brightness_0.97, contrast_1.06, flipped', 'type': 'original', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 68:
#   ID del registro: images/ISIC_0031442.png
#   Vector: [ 0.03049662 -0.00427778 -0.02268718  0.02921443  0.01359738]... (primeros 5 valores)
#   Otros metadatos: {'transformations_info': 'images/ISIC_0031442_rotated_-10_brightness_0.93_contrast_1.02_flipped.png:rotated_-10, brightness_0.93, contrast_1.02, flipped', 'type': 'original', 'associated_images': 'images/ISIC_0031442.png,images/ISIC_0031442_rotated_-10_brightness_0.93_contrast_1.02_flipped.png', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 69:
#   ID del registro: images/ISIC_0031655.png
#   Vector: [ 0.01371433 -0.01285532 -0.04117666  0.02519301 -0.00793396]... (primeros 5 valores)
#   Otros metadatos: {'transformations_info': 'images/ISIC_0031655_brightness_1.05_contrast_0.95_flipped.png:brightness_1.05, contrast_0.95, flipped', 'associated_images': 'images/ISIC_0031655.png,images/ISIC_0031655_brightness_1.05_contrast_0.95_flipped.png', 'image_type': 'original', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 70:
#   ID del registro: images/ISIC_0031831.png
#   Vector: [ 0.03340527 -0.00382861 -0.02610197  0.02018058 -0.01241183]... (primeros 5 valores)
#   Otros metadatos: {'type': 'original', 'image_type': 'original', 'associated_images': 'images/ISIC_0031831.png,images/ISIC_0031831_augmented.png', 'transformations_info': 'images/ISIC_0031831_augmented.png:none'}
# --------------------------------------------------------------------------------
#
# Embedding 71:
#   ID del registro: images/ISIC_0031948.png
#   Vector: [ 0.03172883 -0.01720192 -0.00512559  0.01451804  0.03257167]... (primeros 5 valores)
#   Otros metadatos: {'image_type': 'original', 'transformations_info': 'images/ISIC_0031948_rotated_12_contrast_1.19_flipped.png:rotated_12, contrast_1.19, flipped', 'associated_images': 'images/ISIC_0031948.png,images/ISIC_0031948_rotated_12_contrast_1.19_flipped.png', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 72:
#   ID del registro: images/ISIC_0031981.png
#   Vector: [ 0.00027344 -0.00470603 -0.02586965  0.02464155  0.01238644]... (primeros 5 valores)
#   Otros metadatos: {'image_type': 'original', 'type': 'original', 'associated_images': 'images/ISIC_0031981.png,images/ISIC_0031981_rotated_-10.png', 'transformations_info': 'images/ISIC_0031981_rotated_-10.png:rotated_-10'}
# --------------------------------------------------------------------------------
#
# Embedding 73:
#   ID del registro: images/ISIC_0031987.png
#   Vector: [ 0.01068132  0.00234158 -0.00889558  0.02337731  0.02934256]... (primeros 5 valores)
#   Otros metadatos: {'type': 'original', 'transformations_info': 'images/ISIC_0031987_rotated_9_brightness_1.18_contrast_0.93_flipped.png:rotated_9, brightness_1.18, contrast_0.93, flipped', 'associated_images': 'images/ISIC_0031987.png,images/ISIC_0031987_rotated_9_brightness_1.18_contrast_0.93_flipped.png', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 74:
#   ID del registro: images/ISIC_0032000.png
#   Vector: [-0.02407902 -0.00352176 -0.02104735  0.01874222  0.03560856]... (primeros 5 valores)
#   Otros metadatos: {'associated_images': 'images/ISIC_0032000.png,images/ISIC_0032000_brightness_0.87_contrast_0.91_flipped.png', 'transformations_info': 'images/ISIC_0032000_brightness_0.87_contrast_0.91_flipped.png:brightness_0.87, contrast_0.91, flipped', 'type': 'original', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 75:
#   ID del registro: images/ISIC_0032110.png
#   Vector: [ 0.02113677 -0.01455465 -0.00662071  0.00316786  0.01205785]... (primeros 5 valores)
#   Otros metadatos: {'associated_images': 'images/ISIC_0032110.png,images/ISIC_0032110_flipped.png', 'transformations_info': 'images/ISIC_0032110_flipped.png:flipped', 'image_type': 'original', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 76:
#   ID del registro: images/ISIC_0032150.png
#   Vector: [ 0.03425972 -0.00111171 -0.01417503  0.02081074  0.0195289 ]... (primeros 5 valores)
#   Otros metadatos: {'type': 'original', 'image_type': 'original', 'associated_images': 'images/ISIC_0032150.png,images/ISIC_0032150_flipped.png', 'transformations_info': 'images/ISIC_0032150_flipped.png:flipped'}
# --------------------------------------------------------------------------------
#
# Embedding 77:
#   ID del registro: images/ISIC_0032218.png
#   Vector: [ 0.01098076 -0.00744153 -0.02058938  0.03189134  0.02763683]... (primeros 5 valores)
#   Otros metadatos: {'image_type': 'original', 'associated_images': 'images/ISIC_0032218.png,images/ISIC_0032218_rotated_13.png', 'type': 'original', 'transformations_info': 'images/ISIC_0032218_rotated_13.png:rotated_13'}
# --------------------------------------------------------------------------------
#
# Embedding 78:
#   ID del registro: images/ISIC_0032415.png
#   Vector: [ 0.00877429 -0.00850392 -0.01803001  0.03016694  0.03601572]... (primeros 5 valores)
#   Otros metadatos: {'image_type': 'original', 'transformations_info': 'images/ISIC_0032415_brightness_0.92_flipped.png:brightness_0.92, flipped', 'type': 'original', 'associated_images': 'images/ISIC_0032415.png,images/ISIC_0032415_brightness_0.92_flipped.png'}
# --------------------------------------------------------------------------------
#
# Embedding 79:
#   ID del registro: images/ISIC_0032493.png
#   Vector: [ 0.01972592 -0.00447769 -0.02604528  0.03392862  0.02021309]... (primeros 5 valores)
#   Otros metadatos: {'transformations_info': 'images/ISIC_0032493_rotated_-8_brightness_1.07.png:rotated_-8, brightness_1.07', 'associated_images': 'images/ISIC_0032493.png,images/ISIC_0032493_rotated_-8_brightness_1.07.png', 'type': 'original', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 80:
#   ID del registro: images/ISIC_0032563.png
#   Vector: [ 0.03094118 -0.0046575  -0.03269023  0.01614989 -0.00711074]... (primeros 5 valores)
#   Otros metadatos: {'associated_images': 'images/ISIC_0032563.png,images/ISIC_0032563_rotated_13_contrast_0.86_flipped.png', 'transformations_info': 'images/ISIC_0032563_rotated_13_contrast_0.86_flipped.png:rotated_13, contrast_0.86, flipped', 'type': 'original', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 81:
#   ID del registro: images/ISIC_0032701.png
#   Vector: [ 0.024602    0.00057421 -0.01359574  0.02375505  0.02299483]... (primeros 5 valores)
#   Otros metadatos: {'associated_images': 'images/ISIC_0032701.png,images/ISIC_0032701_flipped.png', 'image_type': 'original', 'type': 'original', 'transformations_info': 'images/ISIC_0032701_flipped.png:flipped'}
# --------------------------------------------------------------------------------
#
# Embedding 82:
#   ID del registro: images/ISIC_0032727.png
#   Vector: [ 0.01449619 -0.00487235 -0.03079671  0.0230245   0.00420056]... (primeros 5 valores)
#   Otros metadatos: {'transformations_info': 'images/ISIC_0032727_rotated_-6_contrast_1.01_flipped.png:rotated_-6, contrast_1.01, flipped', 'image_type': 'original', 'type': 'original', 'associated_images': 'images/ISIC_0032727.png,images/ISIC_0032727_rotated_-6_contrast_1.01_flipped.png'}
# --------------------------------------------------------------------------------
#
# Embedding 83:
#   ID del registro: images/ISIC_0032731.png
#   Vector: [-0.00543496 -0.02026988 -0.02104356  0.01679198  0.01844426]... (primeros 5 valores)
#   Otros metadatos: {'image_type': 'original', 'associated_images': 'images/ISIC_0032731.png,images/ISIC_0032731_brightness_1.18_flipped.png', 'type': 'original', 'transformations_info': 'images/ISIC_0032731_brightness_1.18_flipped.png:brightness_1.18, flipped'}
# --------------------------------------------------------------------------------
#
# Embedding 84:
#   ID del registro: images/ISIC_0032871.png
#   Vector: [ 0.02741379 -0.00411098 -0.02868336  0.00546328  0.0166473 ]... (primeros 5 valores)
#   Otros metadatos: {'image_type': 'original', 'type': 'original', 'associated_images': 'images/ISIC_0032871.png,images/ISIC_0032871_rotated_9_flipped.png', 'transformations_info': 'images/ISIC_0032871_rotated_9_flipped.png:rotated_9, flipped'}
# --------------------------------------------------------------------------------
#
# Embedding 85:
#   ID del registro: images/ISIC_0033053.png
#   Vector: [ 0.0127924  -0.01876537 -0.02191363  0.01176466  0.02438521]... (primeros 5 valores)
#   Otros metadatos: {'associated_images': 'images/ISIC_0033053.png,images/ISIC_0033053_contrast_0.92_flipped.png', 'type': 'original', 'image_type': 'original', 'transformations_info': 'images/ISIC_0033053_contrast_0.92_flipped.png:contrast_0.92, flipped'}
# --------------------------------------------------------------------------------
#
# Embedding 86:
#   ID del registro: images/ISIC_0033055.png
#   Vector: [ 0.01359867 -0.01323834 -0.02127117  0.01146805  0.01119021]... (primeros 5 valores)
#   Otros metadatos: {'type': 'original', 'image_type': 'original', 'transformations_info': 'images/ISIC_0033055_rotated_-1.png:rotated_-1', 'associated_images': 'images/ISIC_0033055.png,images/ISIC_0033055_rotated_-1.png'}
# --------------------------------------------------------------------------------
#
# Embedding 87:
#   ID del registro: images/ISIC_0033103.png
#   Vector: [ 0.00108222 -0.00373612 -0.01364013  0.0058322   0.03008983]... (primeros 5 valores)
#   Otros metadatos: {'associated_images': 'images/ISIC_0033103.png,images/ISIC_0033103_rotated_-9_brightness_1.08_flipped.png', 'type': 'original', 'transformations_info': 'images/ISIC_0033103_rotated_-9_brightness_1.08_flipped.png:rotated_-9, brightness_1.08, flipped', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 88:
#   ID del registro: images/ISIC_0033154.png
#   Vector: [ 0.01306645 -0.01879198 -0.02370193  0.01970185  0.01200713]... (primeros 5 valores)
#   Otros metadatos: {'transformations_info': 'images/ISIC_0033154_rotated_-15_contrast_1.08.png:rotated_-15, contrast_1.08', 'type': 'original', 'associated_images': 'images/ISIC_0033154.png,images/ISIC_0033154_rotated_-15_contrast_1.08.png', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 89:
#   ID del registro: images/ISIC_0033229.png
#   Vector: [ 0.00862189 -0.00978075 -0.01577169  0.01623087  0.0303793 ]... (primeros 5 valores)
#   Otros metadatos: {'transformations_info': 'images/ISIC_0033229_brightness_0.81_contrast_1.09_flipped.png:brightness_0.81, contrast_1.09, flipped', 'associated_images': 'images/ISIC_0033229.png,images/ISIC_0033229_brightness_0.81_contrast_1.09_flipped.png', 'type': 'original', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 90:
#   ID del registro: images/ISIC_0033439.png
#   Vector: [ 2.8989447e-02 -4.5732777e-05 -2.0837491e-02  2.2806369e-02
#   3.3361110e-02]... (primeros 5 valores)
#   Otros metadatos: {'associated_images': 'images/ISIC_0033439.png,images/ISIC_0033439_rotated_11_contrast_0.95_flipped.png', 'transformations_info': 'images/ISIC_0033439_rotated_11_contrast_0.95_flipped.png:rotated_11, contrast_0.95, flipped', 'image_type': 'original', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 91:
#   ID del registro: images/ISIC_0033464.png
#   Vector: [-0.00089072 -0.0173342  -0.02344826  0.03048195  0.0232795 ]... (primeros 5 valores)
#   Otros metadatos: {'transformations_info': 'images/ISIC_0033464_contrast_0.91.png:contrast_0.91', 'type': 'original', 'associated_images': 'images/ISIC_0033464.png,images/ISIC_0033464_contrast_0.91.png', 'image_type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 92:
#   ID del registro: images/ISIC_0033466.png
#   Vector: [ 0.00904134 -0.00865224 -0.01528876  0.01970995  0.02214283]... (primeros 5 valores)
#   Otros metadatos: {'type': 'original', 'image_type': 'original', 'associated_images': 'images/ISIC_0033466.png,images/ISIC_0033466_brightness_1.15_flipped.png', 'transformations_info': 'images/ISIC_0033466_brightness_1.15_flipped.png:brightness_1.15, flipped'}
# --------------------------------------------------------------------------------
#
# Embedding 93:
#   ID del registro: images/ISIC_0033505.png
#   Vector: [ 0.02219354  0.0041886  -0.01838255  0.01932801  0.04327136]... (primeros 5 valores)
#   Otros metadatos: {'type': 'original', 'transformations_info': 'images/ISIC_0033505_contrast_0.86.png:contrast_0.86', 'image_type': 'original', 'associated_images': 'images/ISIC_0033505.png,images/ISIC_0033505_contrast_0.86.png'}
# --------------------------------------------------------------------------------
#
# Embedding 94:
#   ID del registro: images/ISIC_0033786.png
#   Vector: [-0.00275675 -0.00719728 -0.01246944  0.03016599  0.02655018]... (primeros 5 valores)
#   Otros metadatos: {'associated_images': 'images/ISIC_0033786.png,images/ISIC_0033786_rotated_-4_brightness_0.82_flipped.png', 'type': 'original', 'image_type': 'original', 'transformations_info': 'images/ISIC_0033786_rotated_-4_brightness_0.82_flipped.png:rotated_-4, brightness_0.82, flipped'}
# --------------------------------------------------------------------------------
#
# Embedding 95:
#   ID del registro: images/ISIC_0034016.png
#   Vector: [ 0.02357562 -0.02299239 -0.01778263  0.00147513  0.00281878]... (primeros 5 valores)
#   Otros metadatos: {'image_type': 'original', 'transformations_info': 'images/ISIC_0034016_rotated_5_brightness_1.13_flipped.png:rotated_5, brightness_1.13, flipped', 'associated_images': 'images/ISIC_0034016.png,images/ISIC_0034016_rotated_5_brightness_1.13_flipped.png', 'type': 'original'}
# --------------------------------------------------------------------------------
#
# Embedding 96:
#   ID del registro: images/ISIC_0034128.png
# ...
#
# Embedding 223:
#   ID del registro: images/ISIC_0030541_brightness_1.01_contrast_0.99_flipped.png
#   Vector: [ 0.02033612 -0.01682206 -0.03807076  0.01606102  0.01126429]... (primeros 5 valores)
#   Otros metadatos: {'original_image': 'images/ISIC_0030541.png', 'image_type': 'augmented', 'transformations': 'brightness_1.01, contrast_0.99, flipped', 'type': 'transformed'}
# --------------------------------------------------------------------------------
#
# Embedding 224:
#   ID del registro: images/ISIC_0031256_rotated_7_brightness_0.89.png
#   Vector: [ 0.0123255  -0.01412114 -0.02105487  0.01568349  0.0279504 ]... (primeros 5 valores)
#   Otros metadatos: {'type': 'transformed', 'transformations': 'rotated_7, brightness_0.89', 'image_type': 'augmented', 'original_image': 'images/ISIC_0031256.png'}
# --------------------------------------------------------------------------------
#
# Embedding 225:
#   ID del registro: images/ISIC_0031351_brightness_0.82_contrast_1.12_flipped.png
#   Vector: [ 0.01103398 -0.01615845 -0.0235995   0.0119728  -0.00214551]... (primeros 5 valores)
#   Otros metadatos: {'original_image': 'images/ISIC_0031351.png', 'type': 'transformed', 'image_type': 'augmented', 'transformations': 'brightness_0.82, contrast_1.12, flipped'}
# --------------------------------------------------------------------------------
#
# Embedding 226:
#   ID del registro: images/ISIC_0031380_rotated_-9.png
#   Vector: [ 0.00897837 -0.00755948 -0.01936218  0.02052956  0.0110663 ]... (primeros 5 valores)
#   Otros metadatos: {'original_image': 'images/ISIC_0031380.png', 'type': 'transformed', 'transformations': 'rotated_-9', 'image_type': 'augmented'}
# --------------------------------------------------------------------------------
#
# Embedding 227:
#   ID del registro: images/ISIC_0031442_brightness_1.06_contrast_0.88.png
#   Vector: [ 0.03049662 -0.00427778 -0.02268718  0.02921443  0.01359738]... (primeros 5 valores)
#   Otros metadatos: {'type': 'transformed', 'original_image': 'images/ISIC_0031442.png', 'image_type': 'augmented', 'transformations': 'brightness_1.06, contrast_0.88'}
# --------------------------------------------------------------------------------
#
# Embedding 228:
#   ID del registro: images/ISIC_0031655_augmented.png
#   Vector: [ 0.01371433 -0.01285532 -0.04117666  0.02519301 -0.00793396]... (primeros 5 valores)
#   Otros metadatos: {'type': 'transformed', 'original_image': 'images/ISIC_0031655.png', 'transformations': 'none', 'image_type': 'augmented'}
# --------------------------------------------------------------------------------
#
# Embedding 229:
#   ID del registro: images/ISIC_0031831_rotated_13_brightness_1.19_flipped.png
#   Vector: [ 0.03340527 -0.00382861 -0.02610197  0.02018058 -0.01241183]... (primeros 5 valores)
#   Otros metadatos: {'original_image': 'images/ISIC_0031831.png', 'type': 'transformed', 'image_type': 'augmented', 'transformations': 'rotated_13, brightness_1.19, flipped'}
# --------------------------------------------------------------------------------
#
# Embedding 230:
#   ID del registro: images/ISIC_0031948_rotated_4_brightness_0.89_contrast_0.83.png
#   Vector: [ 0.03172883 -0.01720192 -0.00512559  0.01451804  0.03257167]... (primeros 5 valores)
#   Otros metadatos: {'type': 'transformed', 'original_image': 'images/ISIC_0031948.png', 'image_type': 'augmented', 'transformations': 'rotated_4, brightness_0.89, contrast_0.83'}
# --------------------------------------------------------------------------------
#
# Embedding 231:
#   ID del registro: images/ISIC_0031981_brightness_0.86.png
#   Vector: [ 0.00027344 -0.00470603 -0.02586965  0.02464155  0.01238644]... (primeros 5 valores)
#   Otros metadatos: {'original_image': 'images/ISIC_0031981.png', 'transformations': 'brightness_0.86', 'type': 'transformed', 'image_type': 'augmented'}
# --------------------------------------------------------------------------------
#
# Embedding 232:
#   ID del registro: images/ISIC_0031987_rotated_15_contrast_1.07_flipped.png
#   Vector: [ 0.01068132  0.00234158 -0.00889558  0.02337731  0.02934256]... (primeros 5 valores)
#   Otros metadatos: {'type': 'transformed', 'original_image': 'images/ISIC_0031987.png', 'transformations': 'rotated_15, contrast_1.07, flipped', 'image_type': 'augmented'}
# --------------------------------------------------------------------------------
#
# Embedding 233:
#   ID del registro: images/ISIC_0032000_contrast_1.15_flipped.png
#   Vector: [-0.02407902 -0.00352176 -0.02104735  0.01874222  0.03560856]... (primeros 5 valores)
#   Otros metadatos: {'original_image': 'images/ISIC_0032000.png', 'transformations': 'contrast_1.15, flipped', 'type': 'transformed', 'image_type': 'augmented'}
# --------------------------------------------------------------------------------
#
# Embedding 234:
#   ID del registro: images/ISIC_0032110_rotated_-8_brightness_1.19_contrast_1.02.png
#   Vector: [ 0.02113677 -0.01455465 -0.00662071  0.00316786  0.01205785]... (primeros 5 valores)
#   Otros metadatos: {'type': 'transformed', 'image_type': 'augmented', 'transformations': 'rotated_-8, brightness_1.19, contrast_1.02', 'original_image': 'images/ISIC_0032110.png'}
# --------------------------------------------------------------------------------
#
# Embedding 235:
#   ID del registro: images/ISIC_0032150_brightness_0.86_contrast_0.89_flipped.png
#   Vector: [ 0.03425972 -0.00111171 -0.01417503  0.02081074  0.0195289 ]... (primeros 5 valores)
#   Otros metadatos: {'transformations': 'brightness_0.86, contrast_0.89, flipped', 'type': 'transformed', 'original_image': 'images/ISIC_0032150.png', 'image_type': 'augmented'}
# --------------------------------------------------------------------------------
#
# Embedding 236:
#   ID del registro: images/ISIC_0032218_rotated_-10.png
#   Vector: [ 0.01098076 -0.00744153 -0.02058938  0.03189134  0.02763683]... (primeros 5 valores)
#   Otros metadatos: {'type': 'transformed', 'transformations': 'rotated_-10', 'image_type': 'augmented', 'original_image': 'images/ISIC_0032218.png'}
# --------------------------------------------------------------------------------
#
# Embedding 237:
#   ID del registro: images/ISIC_0032415_rotated_-8_contrast_1.05_flipped.png
#   Vector: [ 0.00877429 -0.00850392 -0.01803001  0.03016694  0.03601572]... (primeros 5 valores)
#   Otros metadatos: {'transformations': 'rotated_-8, contrast_1.05, flipped', 'original_image': 'images/ISIC_0032415.png', 'image_type': 'augmented', 'type': 'transformed'}
# --------------------------------------------------------------------------------
#
# Embedding 238:
#   ID del registro: images/ISIC_0032493_rotated_14_brightness_0.95_contrast_0.95.png
#   Vector: [ 0.01972592 -0.00447769 -0.02604528  0.03392862  0.02021309]... (primeros 5 valores)
#   Otros metadatos: {'original_image': 'images/ISIC_0032493.png', 'transformations': 'rotated_14, brightness_0.95, contrast_0.95', 'type': 'transformed', 'image_type': 'augmented'}
# --------------------------------------------------------------------------------
#
# Embedding 239:
#   ID del registro: images/ISIC_0032563_rotated_-8_contrast_0.84.png
#   Vector: [ 0.03094118 -0.0046575  -0.03269023  0.01614989 -0.00711074]... (primeros 5 valores)
#   Otros metadatos: {'original_image': 'images/ISIC_0032563.png', 'image_type': 'augmented', 'transformations': 'rotated_-8, contrast_0.84', 'type': 'transformed'}
# --------------------------------------------------------------------------------
#
# Embedding 240:
#   ID del registro: images/ISIC_0032701_rotated_3_flipped.png
#   Vector: [ 0.024602    0.00057421 -0.01359574  0.02375505  0.02299483]... (primeros 5 valores)
#   Otros metadatos: {'image_type': 'augmented', 'original_image': 'images/ISIC_0032701.png', 'type': 'transformed', 'transformations': 'rotated_3, flipped'}
# --------------------------------------------------------------------------------
#
# Embedding 241:
#   ID del registro: images/ISIC_0032727_brightness_1.07_flipped.png
#   Vector: [ 0.01449619 -0.00487235 -0.03079671  0.0230245   0.00420056]... (primeros 5 valores)
#   Otros metadatos: {'type': 'transformed', 'transformations': 'brightness_1.07, flipped', 'image_type': 'augmented', 'original_image': 'images/ISIC_0032727.png'}
# --------------------------------------------------------------------------------
#
# Embedding 242:
#   ID del registro: images/ISIC_0032731_brightness_1.06_contrast_1.16.png
#   Vector: [-0.00543496 -0.02026988 -0.02104356  0.01679198  0.01844426]... (primeros 5 valores)
#   Otros metadatos: {'type': 'transformed', 'original_image': 'images/ISIC_0032731.png', 'image_type': 'augmented', 'transformations': 'brightness_1.06, contrast_1.16'}
# --------------------------------------------------------------------------------
#
# Embedding 243:
#   ID del registro: images/ISIC_0032871_rotated_-11_flipped.png
#   Vector: [ 0.02741379 -0.00411098 -0.02868336  0.00546328  0.0166473 ]... (primeros 5 valores)
#   Otros metadatos: {'original_image': 'images/ISIC_0032871.png', 'type': 'transformed', 'image_type': 'augmented', 'transformations': 'rotated_-11, flipped'}
# --------------------------------------------------------------------------------
#
# Embedding 244:
#   ID del registro: images/ISIC_0033053_brightness_1.08_contrast_1.09.png
#   Vector: [ 0.0127924  -0.01876537 -0.02191363  0.01176466  0.02438521]... (primeros 5 valores)
#   Otros metadatos: {'transformations': 'brightness_1.08, contrast_1.09', 'image_type': 'augmented', 'type': 'transformed', 'original_image': 'images/ISIC_0033053.png'}
# --------------------------------------------------------------------------------
#
# Embedding 245:
#   ID del registro: images/ISIC_0033055_rotated_10_brightness_1.15_flipped.png
#   Vector: [ 0.01359867 -0.01323834 -0.02127117  0.01146805  0.01119021]... (primeros 5 valores)
#   Otros metadatos: {'type': 'transformed', 'image_type': 'augmented', 'original_image': 'images/ISIC_0033055.png', 'transformations': 'rotated_10, brightness_1.15, flipped'}
# --------------------------------------------------------------------------------
#
# Embedding 246:
#   ID del registro: images/ISIC_0033103_rotated_-7.png
#   Vector: [ 0.00108222 -0.00373612 -0.01364013  0.0058322   0.03008983]... (primeros 5 valores)
#   Otros metadatos: {'type': 'transformed', 'original_image': 'images/ISIC_0033103.png', 'image_type': 'augmented', 'transformations': 'rotated_-7'}
# --------------------------------------------------------------------------------
#
# Embedding 247:
#   ID del registro: images/ISIC_0033154_rotated_13_flipped.png
#   Vector: [ 0.01306645 -0.01879198 -0.02370193  0.01970185  0.01200713]... (primeros 5 valores)
#   Otros metadatos: {'image_type': 'augmented', 'type': 'transformed', 'original_image': 'images/ISIC_0033154.png', 'transformations': 'rotated_13, flipped'}
# --------------------------------------------------------------------------------
#
# Embedding 248:
#   ID del registro: images/ISIC_0033229_brightness_1.01_flipped.png
#   Vector: [ 0.00862189 -0.00978075 -0.01577169  0.01623087  0.0303793 ]... (primeros 5 valores)
#   Otros metadatos: {'transformations': 'brightness_1.01, flipped', 'original_image': 'images/ISIC_0033229.png', 'image_type': 'augmented', 'type': 'transformed'}
# --------------------------------------------------------------------------------
#
# Embedding 249:
#   ID del registro: images/ISIC_0033439_brightness_0.89.png
#   Vector: [ 2.8989447e-02 -4.5732777e-05 -2.0837491e-02  2.2806369e-02
#   3.3361110e-02]... (primeros 5 valores)
#   Otros metadatos: {'original_image': 'images/ISIC_0033439.png', 'image_type': 'augmented', 'type': 'transformed', 'transformations': 'brightness_0.89'}
# --------------------------------------------------------------------------------
#
# Embedding 250:
#   ID del registro: images/ISIC_0033464_brightness_0.99_contrast_1.12_flipped.png
#   Vector: [-0.00089072 -0.0173342  -0.02344826  0.03048195  0.0232795 ]... (primeros 5 valores)
#   Otros metadatos: {'type': 'transformed', 'image_type': 'augmented', 'original_image': 'images/ISIC_0033464.png', 'transformations': 'brightness_0.99, contrast_1.12, flipped'}
# --------------------------------------------------------------------------------
#
# Embedding 251:
#   ID del registro: images/ISIC_0033466_brightness_0.95_flipped.png
#   Vector: [ 0.00904134 -0.00865224 -0.01528876  0.01970995  0.02214283]... (primeros 5 valores)
#   Otros metadatos: {'type': 'transformed', 'image_type': 'augmented', 'transformations': 'brightness_0.95, flipped', 'original_image': 'images/ISIC_0033466.png'}
# --------------------------------------------------------------------------------
#
# Embedding 252:
#   ID del registro: images/ISIC_0033505_brightness_1.06_contrast_0.94_flipped.png
#   Vector: [ 0.02219354  0.0041886  -0.01838255  0.01932801  0.04327136]... (primeros 5 valores)
#   Otros metadatos: {'image_type': 'augmented', 'transformations': 'brightness_1.06, contrast_0.94, flipped', 'original_image': 'images/ISIC_0033505.png', 'type': 'transformed'}
# --------------------------------------------------------------------------------
#
# Embedding 253:
#   ID del registro: images/ISIC_0033786_augmented.png
#   Vector: [-0.00275675 -0.00719728 -0.01246944  0.03016599  0.02655018]... (primeros 5 valores)
#   Otros metadatos: {'original_image': 'images/ISIC_0033786.png', 'type': 'transformed', 'image_type': 'augmented', 'transformations': 'none'}
# --------------------------------------------------------------------------------
#
# Embedding 254:
#   ID del registro: images/ISIC_0034016_brightness_1.09_flipped.png
#   Vector: [ 0.02357562 -0.02299239 -0.01778263  0.00147513  0.00281878]... (primeros 5 valores)
#   Otros metadatos: {'transformations': 'brightness_1.09, flipped', 'type': 'transformed', 'image_type': 'augmented', 'original_image': 'images/ISIC_0034016.png'}
# --------------------------------------------------------------------------------
#
# Embedding 255:
#   ID del registro: images/ISIC_0034128_rotated_-6_brightness_1.06_contrast_0.93_flipped.png
#   Vector: [ 0.00427454 -0.00230343 -0.03143026  0.02389285  0.02376059]... (primeros 5 valores)
#   Otros metadatos: {'transformations': 'rotated_-6, brightness_1.06, contrast_0.93, flipped', 'image_type': 'augmented', 'type': 'transformed', 'original_image': 'images/ISIC_0034128.png'}
# --------------------------------------------------------------------------------
#
# Embedding 256:
#   ID del registro: images/ISIC_0034129_contrast_0.92.png
#   Vector: [ 0.01352043 -0.01510679 -0.02055673  0.01707948 -0.00726165]... (primeros 5 valores)
#   Otros metadatos: {'transformations': 'contrast_0.92', 'type': 'transformed', 'original_image': 'images/ISIC_0034129.png', 'image_type': 'augmented'}
# --------------------------------------------------------------------------------
#
# Embedding 257:
#   ID del registro: images/ISIC_0034144_rotated_-14_brightness_0.84_contrast_0.81.png
#   Vector: [ 0.02255539 -0.00512712 -0.02764391  0.03434591 -0.00240927]... (primeros 5 valores)
#   Otros metadatos: {'image_type': 'augmented', 'original_image': 'images/ISIC_0034144.png', 'transformations': 'rotated_-14, brightness_0.84, contrast_0.81', 'type': 'transformed'}
# --------------------------------------------------------------------------------
#
# Embedding 258:
#   ID del registro: images/ISIC_0034196_brightness_0.97_contrast_1.05_flipped.png
#   Vector: [-0.00603145 -0.02359565 -0.01855343  0.01444226  0.00918422]... (primeros 5 valores)
#   Otros metadatos: {'original_image': 'images/ISIC_0034196.png', 'type': 'transformed', 'image_type': 'augmented', 'transformations': 'brightness_0.97, contrast_1.05, flipped'}
# --------------------------------------------------------------------------------
#
# Embedding 259:
#   ID del registro: images/ISIC_0034222_contrast_1.15_flipped.png
#   Vector: [ 0.01433372 -0.02409759 -0.0287529   0.01377942 -0.00288303]... (primeros 5 valores)
#   Otros metadatos: {'original_image': 'images/ISIC_0034222.png', 'type': 'transformed', 'image_type': 'augmented', 'transformations': 'contrast_1.15, flipped'}
# --------------------------------------------------------------------------------
#
# Resumen:
#   Total de embeddings únicos: 259
#   Total de imágenes (originales + transformadas): 359

# %%
import chromadb
import json
client = chromadb.HttpClient(host="localhost", port=8000)

collection = client.get_collection("text_multimodal_collection")
collection_image = client.get_collection("image_multimodal_collection")
objects = collection.get(include=["metadatas", "documents"])
text_data = collection.get(
    include=["embeddings", "metadatas", "documents"]
)
text_embeddings = text_data["embeddings"]

dataset_pairs = []
dataset_pairs_augmented = []

results = collection_image.query(
    query_embeddings=text_embeddings,
    n_results=1,
    include=["metadatas", "documents", "distances"],
)

# For the augmntation reason we will include 3 rsultst, to catch some of the images that have been modififed.
results_augmented = collection_image.query(
    query_embeddings=text_embeddings,
    n_results=3,
    include=["metadatas", "documents", "distances"],
)
print(results)
print(results_augmented)

for i, text_path in enumerate(text_data["ids"]):
    best_image_path = results["ids"][i][0]
    score = results["distances"][i][0]
    dataset_pairs.append({
        "image": best_image_path,
        "text": text_path,
        "score": score
    })

# in that case we will include 3 results, to catch some of the images that have been modififed.
for i, text_path in enumerate(text_data["ids"]):
    for j in range(3):
        best_image_path = results_augmented["ids"][i][j]
        score = results_augmented["distances"][i][j]
        dataset_pairs_augmented.append({
            "image": best_image_path,
            "text": text_path,
            "score": score
        })

local_filename = "dataset_train.json"
local_filename_augmented = "dataset_train_augmented.json"
with open(local_filename, "w") as f:
    json.dump(dataset_pairs, f)
with open(local_filename_augmented, "w") as f:
    json.dump(dataset_pairs_augmented, f)

minio_client.upload_file(local_filename, new_bucket, local_filename)
minio_client.upload_file(local_filename_augmented, new_bucket, local_filename_augmented)
# Out:
# {'ids': [['images/ISIC_0027249.png'], ['images/ISIC_0027058.png'], ['images/ISIC_0026152.png'], ['images/ISIC_0026803.png'], ['images/ISIC_0026077.png'], ['images/ISIC_0026803.png'], ['images/ISIC_0027058.png'], ['images/ISIC_0027249.png'], ['images/ISIC_0031987.png'], ['images/ISIC_0028103.png'], ['images/ISIC_0029475.png'], ['images/ISIC_0025960.png'], ['images/ISIC_0027999.png'], ['images/ISIC_0026152.png'], ['images/ISIC_0031987.png'], ['images/ISIC_0031380.png'], ['images/ISIC_0029220.png'], ['images/ISIC_0025874.png'], ['images/ISIC_0031442.png'], ['images/ISIC_0025960.png'], ['images/ISIC_0032110.png'], ['images/ISIC_0033505.png'], ['images/ISIC_0031831.png'], ['images/ISIC_0027058.png'], ['images/ISIC_0031981.png'], ['images/ISIC_0030197.png'], ['images/ISIC_0032415.png'], ['images/ISIC_0032727.png'], ['images/ISIC_0029694.png'], ['images/ISIC_0029929.png'], ['images/ISIC_0029263.png'], ['images/ISIC_0025960.png'], ['images/ISIC_0034196.png'], ['images/ISIC_0032731.png'], ['images/ISIC_0032415.png'], ['images/ISIC_0027077.png'], ['images/ISIC_0032415.png'], ['images/ISIC_0027058.png'], ['images/ISIC_0033103.png'], ['images/ISIC_0033103.png'], ['images/ISIC_0031380.png'], ['images/ISIC_0028025.png'], ['images/ISIC_0034196.png'], ['images/ISIC_0031380.png'], ['images/ISIC_0029577.png'], ['images/ISIC_0033229.png'], ['images/ISIC_0034222.png'], ['images/ISIC_0027077.png'], ['images/ISIC_0027058.png'], ['images/ISIC_0027077.png'], ['images/ISIC_0031442.png'], ['images/ISIC_0031831.png'], ['images/ISIC_0025886.png'], ['images/ISIC_0031380.png'], ['images/ISIC_0026077.png'], ['images/ISIC_0032150.png'], ['images/ISIC_0034222.png'], ['images/ISIC_0032415.png'], ['images/ISIC_0031831.png'], ['images/ISIC_0031380.png'], ['images/ISIC_0027249.png'], ['images/ISIC_0029263.png'], ['images/ISIC_0032110.png'], ['images/ISIC_0027710.png'], ['images/ISIC_0032110.png'], ['images/ISIC_0024388.png'], ['images/ISIC_0031831.png'], ['images/ISIC_0031442.png'], ['images/ISIC_0027058.png'], ['images/ISIC_0032415.png'], ['images/ISIC_0027219.png'], ['images/ISIC_0033786.png'], ['images/ISIC_0034196.png'], ['images/ISIC_0034196.png'], ['images/ISIC_0031380.png'], ['images/ISIC_0026803.png'], ['images/ISIC_0031380.png'], ['images/ISIC_0026507.png'], ['images/ISIC_0032415.png'], ['images/ISIC_0031380.png'], ['images/ISIC_0034016.png'], ['images/ISIC_0027058.png'], ['images/ISIC_0030492.png'], ['images/ISIC_0026128.png'], ['images/ISIC_0031987.png'], ['images/ISIC_0031380.png'], ['images/ISIC_0034196.png'], ['images/ISIC_0031380.png'], ['images/ISIC_0029220.png'], ['images/ISIC_0033786.png'], ['images/ISIC_0032563.png'], ['images/ISIC_0031380.png'], ['images/ISIC_0032415.png'], ['images/ISIC_0024853.png'], ['images/ISIC_0027620.png'], ['images/ISIC_0033786.png'], ['images/ISIC_0027058.png'], ['images/ISIC_0032110.png'], ['images/ISIC_0025874.png'], ['images/ISIC_0032110.png'], ['images/ISIC_0027219.png'], ['images/ISIC_0033786.png'], ['images/ISIC_0031380.png'], ['images/ISIC_0026152.png'], ['images/ISIC_0027077.png'], ['images/ISIC_0034222.png'], ['images/ISIC_0034222.png'], ['images/ISIC_0032731.png'], ['images/ISIC_0031831.png'], ['images/ISIC_0034222.png'], ['images/ISIC_0032150.png'], ['images/ISIC_0024388.png'], ['images/ISIC_0027249.png'], ['images/ISIC_0030055.png'], ['images/ISIC_0027249.png'], ['images/ISIC_0027077.png'], ['images/ISIC_0031831.png'], ['images/ISIC_0032110.png'], ['images/ISIC_0025118.png'], ['images/ISIC_0027249.png'], ['images/ISIC_0027249.png'], ['images/ISIC_0031442.png'], ['images/ISIC_0032727.png'], ['images/ISIC_0027077.png'], ['images/ISIC_0032150.png'], ['images/ISIC_0031380.png'], ['images/ISIC_0031442.png'], ['images/ISIC_0026283.png'], ['images/ISIC_0029851.png'], ['images/ISIC_0031380.png'], ['images/ISIC_0027249.png'], ['images/ISIC_0027077.png'], ['images/ISIC_0027249.png'], ['images/ISIC_0025960.png'], ['images/ISIC_0031442.png'], ['images/ISIC_0032731.png'], ['images/ISIC_0027249.png'], ['images/ISIC_0029 ...
# {'ids': [['images/ISIC_0027249.png', 'images/ISIC_0032727.png', 'images/ISIC_0032415.png'], ['images/ISIC_0027058.png', 'images/ISIC_0029475.png', 'images/ISIC_0026152.png'], ['images/ISIC_0026152.png', 'images/ISIC_0026803.png', 'images/ISIC_0029475.png'], ['images/ISIC_0026803.png', 'images/ISIC_0029475.png', 'images/ISIC_0032727.png'], ['images/ISIC_0026077.png', 'images/ISIC_0032110.png', 'images/ISIC_0031351.png'], ['images/ISIC_0026803.png', 'images/ISIC_0032110.png', 'images/ISIC_0032727.png'], ['images/ISIC_0027058.png', 'images/ISIC_0025960.png', 'images/ISIC_0030197.png'], ['images/ISIC_0027249.png', 'images/ISIC_0033505.png', 'images/ISIC_0032731.png'], ['images/ISIC_0031987.png', 'images/ISIC_0032563.png', 'images/ISIC_0032150.png'], ['images/ISIC_0028103.png', 'images/ISIC_0031987.png', 'images/ISIC_0027058.png'], ['images/ISIC_0029475.png', 'images/ISIC_0026803.png', 'images/ISIC_0026152.png'], ['images/ISIC_0025960.png', 'images/ISIC_0032727.png', 'images/ISIC_0034196.png'], ['images/ISIC_0027999.png', 'images/ISIC_0034128.png', 'images/ISIC_0032871.png'], ['images/ISIC_0026152.png', 'images/ISIC_0034196.png', 'images/ISIC_0030492.png'], ['images/ISIC_0031987.png', 'images/ISIC_0028103.png', 'images/ISIC_0034196.png'], ['images/ISIC_0031380.png', 'images/ISIC_0028381.png', 'images/ISIC_0028175.png'], ['images/ISIC_0029220.png', 'images/ISIC_0032000.png', 'images/ISIC_0033786.png'], ['images/ISIC_0025874.png', 'images/ISIC_0028175.png', 'images/ISIC_0032110.png'], ['images/ISIC_0031442.png', 'images/ISIC_0032150.png', 'images/ISIC_0031380.png'], ['images/ISIC_0025960.png', 'images/ISIC_0029577.png', 'images/ISIC_0028103.png'], ['images/ISIC_0032110.png', 'images/ISIC_0026283.png', 'images/ISIC_0027710.png'], ['images/ISIC_0033505.png', 'images/ISIC_0025960.png', 'images/ISIC_0026803.png'], ['images/ISIC_0031831.png', 'images/ISIC_0033505.png', 'images/ISIC_0025118.png'], ['images/ISIC_0027058.png', 'images/ISIC_0033466.png', 'images/ISIC_0029649.png'], ['images/ISIC_0031981.png', 'images/ISIC_0030197.png', 'images/ISIC_0025874.png'], ['images/ISIC_0030197.png', 'images/ISIC_0027841.png', 'images/ISIC_0029623.png'], ['images/ISIC_0032415.png', 'images/ISIC_0029577.png', 'images/ISIC_0033505.png'], ['images/ISIC_0032727.png', 'images/ISIC_0026152.png', 'images/ISIC_0033505.png'], ['images/ISIC_0029694.png', 'images/ISIC_0027710.png', 'images/ISIC_0033786.png'], ['images/ISIC_0029929.png', 'images/ISIC_0029851.png', 'images/ISIC_0034196.png'], ['images/ISIC_0029263.png', 'images/ISIC_0031351.png', 'images/ISIC_0029694.png'], ['images/ISIC_0025960.png', 'images/ISIC_0034016.png', 'images/ISIC_0025118.png'], ['images/ISIC_0034196.png', 'images/ISIC_0029263.png', 'images/ISIC_0028103.png'], ['images/ISIC_0032731.png', 'images/ISIC_0031380.png', 'images/ISIC_0033103.png'], ['images/ISIC_0032415.png', 'images/ISIC_0030197.png', 'images/ISIC_0026803.png'], ['images/ISIC_0027077.png', 'images/ISIC_0031442.png', 'images/ISIC_0029896.png'], ['images/ISIC_0032415.png', 'images/ISIC_0032727.png', 'images/ISIC_0026152.png'], ['images/ISIC_0027058.png', 'images/ISIC_0031831.png', 'images/ISIC_0032731.png'], ['images/ISIC_0033103.png', 'images/ISIC_0031442.png', 'images/ISIC_0025118.png'], ['images/ISIC_0033103.png', 'images/ISIC_0031442.png', 'images/ISIC_0027058.png'], ['images/ISIC_0031380.png', 'images/ISIC_0033786.png', 'images/ISIC_0025118.png'], ['images/ISIC_0028025.png', 'images/ISIC_0026077.png', 'images/ISIC_0028175.png'], ['images/ISIC_0034196.png', 'images/ISIC_0032563.png', 'images/ISIC_0026077.png'], ['images/ISIC_0031380.png', 'images/ISIC_0034196.png', 'images/ISIC_0032415.png'], ['images/ISIC_0029577.png', 'images/ISIC_0033229.png', 'images/ISIC_0029024.png'], ['images/ISIC_0033229.png', 'images/ISIC_0033103.png', 'images/ISIC_0033786.png'], ['images/ISIC_0034222.png', 'images/ISIC_0027058.png', 'images/ISIC_0025960.png'], ['images/ISIC_0027077.png', 'images/ISIC_0033229.png', 'images/ISIC_0027209.png'], ['image ...
